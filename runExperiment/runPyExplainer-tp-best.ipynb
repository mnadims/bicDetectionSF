# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import precision_recall_fscore_support
from collections import Counter
from IPython.display import clear_output

from pyexplainer.pyexplainer_pyexplainer import PyExplainer
from pyexplainer.pyexplainer_pyexplainer import AutoSpearman

# %%
ranked_tp_features = open("ranked_feature_names/ranked_qt_tp_JITLine.txt").read().split('\n')[0:-1]
#ranked_tp_features = open("mydataset/100_correctly_predicted_buggy_fetature_names.txt").read().split('\n')[0:-1]
train_commit = open("mydataset/train_commit.txt").read().split('\n')[0:-1]
test_commit = open("mydataset/test_commit.txt").read().split('\n')[0:-1]
train_label = open("mydataset/train_label.txt").read().split('\n')[0:-1]
test_label = open("mydataset/test_label.txt").read().split('\n')[0:-1]
print(ranked_tp_features[0:10])
print(len(train_commit), len(test_commit), len(train_label), len(test_label))
# Out:
# ['expr-name', 'expr-call-argument-expr-name', 'decl-name', 'expr-operator', 'expr-call-name', 'if-condition-expr-operator', 'decl-type-name', 'function_decl-name', 'decl-argument-expr-name', 'expr-call-name-name']
# 1709 734 1709 734

# %%
def findCorrectBuggy(yTest, yPredict):
    #length of these arrays will determine the number of correct buggy and non buggy commits
    CorrectBuggyCommits = []
    CorrectNonBuggyCommits = []
    
    #CorrectbuggyCount = 0
    #CorrectNonbuggyCount = 0
    for index in range(len(yTest)):
        if(yTest[index] == 1 and yPredict[index] == 1):
            #CorrectbuggyCount += 1
            CorrectBuggyCommits.append(test_commit[index])
        elif(yTest[index] == 0 and yPredict[index] == 0):
            #CorrectNonbuggyCount += 1
            CorrectNonBuggyCommits.append(test_commit[index])
            
    return CorrectBuggyCommits, CorrectNonBuggyCommits

# %%
# [['commit_id']+ranked_tp_features[0:]]
file_path = "mydataset/"
best_features = 6
#read three data files and merge into one dataframe 'inner_join' by 'commit_id'
# df_tp = pd.merge(pd.read_csv(file_path+ "qtbase_tp_dataset.csv"), #TP: Token Pattern Features
#                  pd.read_csv(file_path+ "qt_metrics.csv"),
#                  on='commit_id')[['commit_id']+ranked_tp_features[0:]]
df_tp = pd.read_csv(file_path+ "qtbase_tp_dataset.csv")[['commit_id']+ranked_tp_features[0:best_features]] #TP: Token Pattern Features
                 
df_tp.replace([np.inf, -np.inf], np.nan, inplace=True)
df_tp.fillna(0, inplace=True)

df_train = df_tp[df_tp["commit_id"].isin(train_commit)]
df_train = df_train.reset_index().drop(columns=['index'])

df_test = df_tp[df_tp["commit_id"].isin(test_commit)]
df_test = df_test.reset_index().drop(columns=['index'])

df_train.columns = ['col_' + str(col).replace('-', '_') for col in df_train.columns]
df_test.columns = ['col_' + str(col).replace('-', '_') for col in df_test.columns]

print(df_train.shape, df_test.shape)

df_train["bugcount"] = train_label
df_test["bugcount"] = test_label

print(df_train.shape, df_test.shape)
# Out:
# (1709, 7) (734, 7)
# (1709, 8) (734, 8)

# %%
df_test.iloc[1:2, 2:]
# Out:
#    col_expr_call_argument_expr_name  col_decl_name  col_expr_operator  \
# 1                                 0              8                 31
#
#    col_expr_call_name  col_if_condition_expr_operator bugcount
# 1                   0                               0        1

# %%
y_train = df_train["bugcount"]
X_train = df_train.drop(['col_commit_id', 'bugcount'], axis=1)

y_test = df_test["bugcount"]
X_test = df_test.drop(['col_commit_id', 'bugcount'], axis=1)

rf_model = RandomForestClassifier(max_depth=100, random_state=42, n_estimators=100)

# %%
print(X_train.shape, y_train.shape)
#print(y_test.shape, list(y_test))
#print(list(y_preds.astype('int32')), "\n", list(y_test['bugcount'].astype('int32')))
# Out:
# (1709, 6) (1709,)

# %%
#run again for the best values: 
# X_train = X_train[list_features[0:best_features]]
# X_test = X_test[list_features[0:best_features]] 
rf_model = RandomForestClassifier(random_state=42)
rf_model.fit(X_train, y_train.values.ravel())
y_preds = rf_model.predict(X_test) 

CorrectBuggyCommits, CorrectNonBuggyCommits = findCorrectBuggy(list(y_test.astype('int32')), 
                                                                   list(y_preds.astype('int32')))

print("Best Number of Features:", best_features)
print("Number of Correct Buggy Commit Prediction: ", len(CorrectBuggyCommits))
print("Number of Correct Non-Buggy Commit Prediction: ", len(CorrectNonBuggyCommits))
# Out:
# Best Number of Features: 6
# Number of Correct Buggy Commit Prediction:  112
# Number of Correct Non-Buggy Commit Prediction:  267

# %%
# create a DataFrame which only has predicted label column
y_preds = pd.DataFrame(data={'PredictedBug': y_preds}, index=df_test.index) 
#y_preds.head(3)

combined_testing_data = X_test.join(y_test.to_frame())
combined_testing_data = combined_testing_data.join(y_preds)
combined_testing_data.head(3)
# total num of rows
total_rows = len(combined_testing_data)

# %%
correctly_predicted_data = combined_testing_data[combined_testing_data['bugcount']==combined_testing_data['PredictedBug']]
correctly_predicted_rows = len(correctly_predicted_data)
print("Total testing data:", total_rows)
print('The model correctly predicted ', round((correctly_predicted_rows / total_rows), 3) * 100, '% of testing data')
# Out:
# Total testing data: 734
# The model correctly predicted  51.6 % of testing data

# %%
print(Counter(correctly_predicted_data['bugcount']))
# Out:
# Counter({'0': 267, '1': 112})

# %%
#Takes only the correctly predicted buggy data
correctly_predicted_bug = correctly_predicted_data[correctly_predicted_data['bugcount']=='1']
print(correctly_predicted_bug.shape)
#correctly_predicted_bug.head(3)
# Out:
# (112, 8)

# %%
# select all rows and feature cols
feature_cols = correctly_predicted_bug.iloc[:, :-2]
# selected all rows and one label col (either RealBug or PredictedBug is fine since they are the same)
label_col = correctly_predicted_bug.iloc[:, -2]

# %%
pyexp = PyExplainer(X_train = X_train,
                    y_train = y_train,
                    indep = X_train.columns,
                    dep = 'bugcount',
                    blackbox_model = rf_model)

# %%
list_of_rules = []
selected_row = 0
while(selected_row < len(feature_cols)):
    clear_output(wait=True)
    print("Working for: ", selected_row, "/", len(feature_cols))
    # select the row in X_test which contains all of the feature values
    X_explain = feature_cols.iloc[[selected_row]]
    # select the corresponding label from the DataFrame that we just created above
    y_explain = label_col.iloc[[selected_row]]

    #this will reset the previous column to make it zero and drop the column created by reset function. 
    #It is important for .visualize function, bug is in the visualize function. 
    X_explain = X_explain.reset_index().drop(columns=['index'])
    #y_explain do not need it
    #y_explain = y_explain.reset_index().drop(columns=['index']).squeeze()

    created_rules = pyexp.explain(X_explain=X_explain,
                                  y_explain=y_explain,
                                  search_function='crossoverinterpolation',
                                  random_state=0,
                                  reuse_local_model=True)
    
    list_of_rules.append(created_rules)
    selected_row +=1

# Please use the code below to visualise the generated PyExplainer explanation (What-If interactive visualisation).
#pyexp.visualise(created_rules, title="Why this file is defect-introducing ?")
# Out:
# Working for:  111 / 112
# Random Perturbation only generated one class for the prediction column which means
#                      Random Perturbation is not compatible with the current data.
#                      The 'Crossover and Interpolation' approach is used as the alternative.

# %%
print(len(list_of_rules))
# Out:
# 112

# %%
rule_index = 4
pyexp.visualise(list_of_rules[rule_index], title="Why this file is defect-introducing ?")
# Out:
# HBox(children=(Label(value='Risk Score: '), FloatProgress(value=0.0, bar_style='info', layout=Layout(width='40…
# Output(layout=Layout(border='3px solid black'))
# FloatSlider(value=1.0, continuous_update=False, description='#1 The value of col_if_condition_expr_operator is…
# FloatSlider(value=1.0, continuous_update=False, description='#2 The value of col_decl_name is less than 1', la…

# %%
#list_of_rules[rule_index].keys()
print(list_of_rules[rule_index]['top_k_positive_rules']['rule'])
# Out:
# 0      col_expr_name <= 9.490000247955322 & col_expr_...
# 1      col_expr_name <= 6.789999961853027 & col_expr_...
# 2      col_decl_name <= 8.25 & col_expr_call_name <= ...
# 3      col_decl_name > 0.3349999934434891 & col_if_co...
# 4      col_decl_name > 1.2549999952316284 & col_expr_...
#                              ...
# 115    col_decl_name > 1.2649999856948853 & col_decl_...
# 116    col_decl_name <= 8.934999942779541 & col_decl_...
# 117    col_if_condition_expr_operator <= 2.5750000476...
# 118    col_expr_call_argument_expr_name > 5.565000057...
# 119    col_if_condition_expr_operator > 13.0500001907...
# Name: rule, Length: 120, dtype: object

# %%
BuggyRuleDataset = [['commit_id', 'rule', 'counter' ]]
buggy_rule_features=[]
for rule_index in range(len(list_of_rules)):    
    single_rules = []
    for r in list_of_rules[rule_index]['top_k_positive_rules']['rule']:
        for sr in r.split('&'):
            single_rules.append(sr.strip())
            
    counted_rules = Counter(single_rules)
    for cr in counted_rules:
        BuggyRuleDataset.append([CorrectBuggyCommits[rule_index], cr.replace('col_', ''), counted_rules[cr]])
        if(cr.split()[0] not in buggy_rule_features):
            buggy_rule_features.append(cr.split()[0])

# %%
for br in BuggyRuleDataset:
    print(br)
# Out:
# ['commit_id', 'rule', 'counter']
# ['260bfaf056c08330ec2ed292e8d9def550e662ec', 'expr_name <= 9.490000247955322', 1]
# ['260bfaf056c08330ec2ed292e8d9def550e662ec', 'expr_call_argument_expr_name > 3.5149999856948853', 1]
# ['260bfaf056c08330ec2ed292e8d9def550e662ec', 'decl_name > 5.799999952316284', 1]
# ['260bfaf056c08330ec2ed292e8d9def550e662ec', 'decl_name <= 15.420000076293945', 1]
# ['260bfaf056c08330ec2ed292e8d9def550e662ec', 'if_condition_expr_operator > 7.664999961853027', 1]
# ['260bfaf056c08330ec2ed292e8d9def550e662ec', 'expr_name <= 6.789999961853027', 1]
# ['260bfaf056c08330ec2ed292e8d9def550e662ec', 'expr_call_name <= 9.945000171661377', 1]
# ['260bfaf056c08330ec2ed292e8d9def550e662ec', 'expr_operator <= 7.359999895095825', 1]
# ['260bfaf056c08330ec2ed292e8d9def550e662ec', 'expr_call_name > 0.5249999761581421', 1]
# ['260bfaf056c08330ec2ed292e8d9def550e662ec', 'decl_name > 1.2549999952316284', 1]
# ['260bfaf056c08330ec2ed292e8d9def550e662ec', 'expr_call_name > 0.6699999868869781', 1]
# ['260bfaf056c08330ec2ed292e8d9def550e662ec', 'expr_operator <= 10.369999885559082', 1]
# ['260bfaf056c08330ec2ed292e8d9def550e662ec', 'decl_name <= 5.615000009536743', 1]
# ['260bfaf056c08330ec2ed292e8d9def550e662ec', 'if_condition_expr_operator > 0.4400000050663948', 1]
# ['260bfaf056c08330ec2ed292e8d9def550e662ec', 'expr_call_argument_expr_name <= 0.9399999976158142', 1]
# ['260bfaf056c08330ec2ed292e8d9def550e662ec', 'expr_call_argument_expr_name <= 6.490000009536743', 1]
# ['260bfaf056c08330ec2ed292e8d9def550e662ec', 'decl_name > 1.3300000429153442', 1]
# ['260bfaf056c08330ec2ed292e8d9def550e662ec', 'expr_call_name <= 9.980000019073486', 2]
# ['260bfaf056c08330ec2ed292e8d9def550e662ec', 'expr_call_argument_expr_name <= 7.234999895095825', 1]
# ['260bfaf056c08330ec2ed292e8d9def550e662ec', 'expr_call_name <= 1.034999966621399', 1]
# ['260bfaf056c08330ec2ed292e8d9def550e662ec', 'expr_name <= 12.690000057220459', 1]
# ['260bfaf056c08330ec2ed292e8d9def550e662ec', 'expr_name <= 1.4700000286102295', 1]
# ['260bfaf056c08330ec2ed292e8d9def550e662ec', 'decl_name > 1.2350000143051147', 1]
# ['260bfaf056c08330ec2ed292e8d9def550e662ec', 'expr_call_argument_expr_name <= 6.1000001430511475', 1]
# ['260bfaf056c08330ec2ed292e8d9def550e662ec', 'decl_name > 1.8450000286102295', 1]
# ['260bfaf056c08330ec2ed292e8d9def550e662ec', 'if_condition_expr_operator > 0.4050000011920929', 1]
# ['260bfaf056c08330ec2ed292e8d9def550e662ec', 'expr_call_argument_expr_name > 0.4950000047683716', 1]
# ['260bfaf056c08330ec2ed292e8d9def550e662ec', 'expr_operator > 0.3799999952316284', 1]
# ['260bfaf056c08330ec2ed292e8d9def550e662ec', 'expr_call_name > -2.8100000619888306', 2]
# ['260bfaf056c08330ec2ed292e8d9def550e662ec', 'expr_call_argument_expr_name <= 6.769999980926514', 1]
# ['260bfaf056c08330ec2ed292e8d9def550e662ec', 'expr_name > 3.8149999380111694', 2]
# ['260bfaf056c08330ec2ed292e8d9def550e662ec', 'expr_call_name <= 12.440000057220459', 2]
# ['260bfaf056c08330ec2ed292e8d9def550e662ec', 'expr_call_name > 4.690000057220459', 1]
# ['260bfaf056c08330ec2ed292e8d9def550e662ec', 'decl_name <= 14.365000247955322', 1]
# ['260bfaf056c08330ec2ed292e8d9def550e662ec', 'expr_call_name <= 15.200000286102295', 1]
# ['260bfaf056c08330ec2ed292e8d9def550e662ec', 'decl_name > 1.1850000023841858', 2]
# ['260bfaf056c08330ec2ed292e8d9def550e662ec', 'expr_call_argument_expr_name <= 4.735000133514404', 1]
# ['260bfaf056c08330ec2ed292e8d9def550e662ec', 'expr_operator <= 24.265000343322754', 1]
# ['260bfaf056c08330ec2ed292e8d9def550e662ec', 'decl_name <= 15.635000228881836', 1]
# ['260bfaf056c08330ec2ed292e8d9def550e662ec', 'expr_operator > 7.440000057220459', 1]
# ['260bfaf056c08330ec2ed292e8d9def550e662ec', 'expr_operator > -0.9099999964237213', 1]
# ['260bfaf056c08330ec2ed292e8d9def550e662ec', 'decl_name > 0.6399999856948853', 1]
# ['260bfaf056c08330ec2ed292e8d9def550e662ec', 'decl_name > 0.3050000071525574', 1]
# ['260bfaf056c08330ec2ed292e8d9def550e662ec', 'expr_operator > 0.044999999925494194', 1]
# ['260bfaf056c08330ec2ed292e8d9def550e662ec', 'expr_operator <= 2.5999999046325684', 1]
# ['260bfaf056c08330ec2ed292e8d9def550e662ec', 'expr_operator > 1.475000023841858', 1]
# ['260bfaf056c08330ec2ed292e8d9def550e662ec', 'expr_name <= 7.115000009536743', 1]
# ['260bfaf056c08330ec2ed292e8d9def550e662ec', 'expr_call_argument_expr_name > -1.1299999952316284', 1]
# ['260bfaf056c08330ec2ed292e8d9def550e662ec', 'decl_name <= 1.6349999904632568', 3]
# ['260bfaf056c08330ec2ed292e8d9def550e662ec', 'expr_operator > 0.47999998927116394', 1]
# ['260bfaf056c08330ec2ed292e8d9def550e662ec', 'expr_operator >
 1]
# ['6a802158597ae8b58b8c8304465f62b5b02ce9ce', 'expr_operator > -21.600000381469727', 1]
# ['6a802158597ae8b58b8c8304465f62b5b02ce9ce', 'decl_name > 22.41999912261963', 1]
# ['6a802158597ae8b58b8c8304465f62b5b02ce9ce', 'expr_call_argument_expr_name > 0.9699999988079071', 1]
# ['6a802158597ae8b58b8c8304465f62b5b02ce9ce', 'expr_operator <= 1.2300000190734863', 1]
# ['6a802158597ae8b58b8c8304465f62b5b02ce9ce', 'expr_operator > 0.4649999886751175', 1]
# ['6a802158597ae8b58b8c8304465f62b5b02ce9ce', 'expr_name <= 15.40500020980835', 1]
# ['6a802158597ae8b58b8c8304465f62b5b02ce9ce', 'expr_call_name <= 19.59000015258789', 1]
# ['6a802158597ae8b58b8c8304465f62b5b02ce9ce', 'expr_call_argument_expr_name <= 6.2850000858306885', 1]
# ['6a802158597ae8b58b8c8304465f62b5b02ce9ce', 'expr_call_argument_expr_name > 4.684999942779541', 1]
# ['6a802158597ae8b58b8c8304465f62b5b02ce9ce', 'expr_operator > -20.21500015258789', 1]
# ['6a802158597ae8b58b8c8304465f62b5b02ce9ce', 'expr_call_name > 15.03000020980835', 1]
# ['6a802158597ae8b58b8c8304465f62b5b02ce9ce', 'expr_name > 10.704999923706055', 1]
# ['6a802158597ae8b58b8c8304465f62b5b02ce9ce', 'expr_operator > 22.329999923706055', 1]
# ['6a802158597ae8b58b8c8304465f62b5b02ce9ce', 'expr_name > 8.235000133514404', 1]
# ['6a802158597ae8b58b8c8304465f62b5b02ce9ce', 'decl_name > -6.360000133514404', 1]
# ['6a802158597ae8b58b8c8304465f62b5b02ce9ce', 'if_condition_expr_operator > 4.315000057220459', 1]
# ['6a802158597ae8b58b8c8304465f62b5b02ce9ce', 'expr_call_argument_expr_name > 5.5950000286102295', 1]
# ['6a802158597ae8b58b8c8304465f62b5b02ce9ce', 'expr_call_name > 12.825000286102295', 1]
# ['6a802158597ae8b58b8c8304465f62b5b02ce9ce', 'decl_name > 8.400000095367432', 1]
# ['6a802158597ae8b58b8c8304465f62b5b02ce9ce', 'decl_name <= 14.565000057220459', 1]
# ['6a802158597ae8b58b8c8304465f62b5b02ce9ce', 'decl_name > 14.565000057220459', 1]
# ['6a802158597ae8b58b8c8304465f62b5b02ce9ce', 'decl_name <= 15.550000190734863', 1]
# ['6a802158597ae8b58b8c8304465f62b5b02ce9ce', 'if_condition_expr_operator > 6.200000047683716', 1]
# ['6a802158597ae8b58b8c8304465f62b5b02ce9ce', 'if_condition_expr_operator > 3.0649999380111694', 1]
# ['6a802158597ae8b58b8c8304465f62b5b02ce9ce', 'decl_name > 15.389999866485596', 1]
# ['6a802158597ae8b58b8c8304465f62b5b02ce9ce', 'expr_name > -7.2799999713897705', 1]
# ['6a802158597ae8b58b8c8304465f62b5b02ce9ce', 'expr_name > -3.384999990463257', 1]
# ['6a802158597ae8b58b8c8304465f62b5b02ce9ce', 'decl_name > 1.2649999856948853', 1]
# ['6a802158597ae8b58b8c8304465f62b5b02ce9ce', 'decl_name > 6.0950000286102295', 1]
# ['6a802158597ae8b58b8c8304465f62b5b02ce9ce', 'expr_call_argument_expr_name <= 0.9449999928474426', 1]
# ['6a802158597ae8b58b8c8304465f62b5b02ce9ce', 'expr_call_argument_expr_name <= 0.7250000238418579', 1]
# ['6a802158597ae8b58b8c8304465f62b5b02ce9ce', 'if_condition_expr_operator <= 14.46500015258789', 1]
# ['6a802158597ae8b58b8c8304465f62b5b02ce9ce', 'decl_name > 6.069999933242798', 1]
# ['6a802158597ae8b58b8c8304465f62b5b02ce9ce', 'decl_name <= 8.934999942779541', 1]
# ['6a802158597ae8b58b8c8304465f62b5b02ce9ce', 'decl_name <= 15.065000057220459', 1]
# ['6a802158597ae8b58b8c8304465f62b5b02ce9ce', 'decl_name > 10.875', 1]
# ['6a802158597ae8b58b8c8304465f62b5b02ce9ce', 'if_condition_expr_operator <= 2.575000047683716', 1]
# ['6a802158597ae8b58b8c8304465f62b5b02ce9ce', 'expr_call_argument_expr_name > 5.565000057220459', 1]
# ['6a802158597ae8b58b8c8304465f62b5b02ce9ce', 'decl_name > 13.429999828338623', 1]
# ['6a802158597ae8b58b8c8304465f62b5b02ce9ce', 'expr_call_name > 9.934999942779541', 1]
# ['6a802158597ae8b58b8c8304465f62b5b02ce9ce', 'if_condition_expr_operator > 16.899999618530273', 1]
# ['6a802158597ae8b58b8c8304465f62b5b02ce9ce', 'if_condition_expr_operator <= 5.065000057220459', 1]
# ['6a802158597ae8b58b8c8304465f62b5b02ce9ce', 'if_condition_expr_operator <= -1.7549999952316284', 1]
# ['6a802158597ae8b58b8c8304465f62b5b02ce9ce', 'if_condition_expr_operator > 13.050000190734863', 1]
# ['6a802158597ae8b58b8c8304465f62b5b02ce9ce', 'if_condition_expr_operator <= 14.050000190734863', 1]
# ['6a802158597ae8b58b8c8304465f62b5b02ce9ce', 'expr_name <= 3.174999952316284', 1]

# %%
print(len(buggy_rule_features))
for brf in buggy_rule_features:
    print(brf.replace('col_', '').replace('_', '-'))
# Out:
# 6
# expr-name
# expr-call-argument-expr-name
# decl-name
# if-condition-expr-operator
# expr-call-name
# expr-operator

# %%
rule_report = []
list_of_rules = []
for br in BuggyRuleDataset:
    list_of_rules.append(br[1])

counted_rule = Counter(list_of_rules)
for cr in counted_rule:
    rule_report.append([cr, counted_rule[cr]])

# %%
sorted_rules = pd.DataFrame(rule_report, columns=['rule', 'count']).sort_values(by=['count'], ascending=False)

# %%
final_text = "Count, Rule\n"
for i in sorted_rules.index:
    final_text += str(sorted_rules['count'][i])+": "+sorted_rules['rule'][i]+'\n'
    
print(final_text)
# Out:
# Count, Rule
# 112: decl_name <= -0.3149999976158142
# 110: if_condition_expr_operator <= 7.805000066757202
# 110: expr_operator <= 2.415000081062317
# 110: expr_call_argument_expr_name > 6.015000104904175
# 109: decl_name <= 15.315000057220459
# 109: expr_operator > 25.09000015258789
# 109: expr_name <= 9.529999732971191
# 109: decl_name <= 9.684999942779541
# 109: expr_call_name > 12.440000057220459
# 109: if_condition_expr_operator > 14.375
# 108: if_condition_expr_operator <= 1.60999995470047
# 108: expr_call_argument_expr_name > 7.860000133514404
# 108: if_condition_expr_operator <= 6.53000020980835
# 108: decl_name <= 15.635000228881836
# 108: expr_call_name > 11.970000267028809
# 108: decl_name > 1.784999966621399
# 108: expr_name <= -3.4950000047683716
# 107: expr_call_argument_expr_name > -4.2749998569488525
# 106: decl_name > 1.1850000023841858
# 106: if_condition_expr_operator <= 15.315000057220459
# 106: expr_operator > 0.4699999988079071
# 106: expr_call_argument_expr_name <= 0.5049999952316284
# 106: expr_call_name <= 9.920000076293945
# 106: expr_operator <= 24.265000343322754
# 106: if_condition_expr_operator > 0.4050000011920929
# 105: expr_name > 7.069999933242798
# 105: if_condition_expr_operator <= 14.190000057220459
# 105: expr_operator > 0.4649999886751175
# 105: expr_operator <= 1.2300000190734863
# 105: expr_name > 8.235000133514404
# 105: if_condition_expr_operator <= 2.575000047683716
# 105: decl_name > 1.2450000047683716
# 105: expr_call_argument_expr_name <= 7.204999923706055
# 105: if_condition_expr_operator > 6.305000066757202
# 105: decl_name <= 1.5999999642372131
# 105: expr_call_argument_expr_name <= 4.735000133514404
# 105: expr_call_name <= 13.460000038146973
# 105: expr_call_name <= 15.200000286102295
# 105: decl_name <= -6.360000133514404
# 105: expr_call_name <= 0.08500000089406967
# 105: decl_name <= 1.4100000262260437
# 105: expr_operator > 17.270000457763672
# 104: if_condition_expr_operator > 6.200000047683716
# 104: expr_call_argument_expr_name > 0.4950000047683716
# 104: if_condition_expr_operator > 3.0649999380111694
# 104: decl_name <= 13.485000133514404
# 104: expr_operator <= 27.350000381469727
# 104: decl_name <= 15.550000190734863
# 104: expr_call_name <= 12.71500015258789
# 104: if_condition_expr_operator > 7.005000114440918
# 104: expr_call_argument_expr_name <= 6.1000001430511475
# 104: decl_name > 1.8450000286102295
# 104: decl_name <= -4.144999980926514
# 104: expr_operator > 0.3799999952316284
# 104: expr_call_name > -2.8100000619888306
# 104: decl_name <= 6.335000038146973
# 104: decl_name > 10.37999963760376
# 104: decl_name <= 5.9649999141693115
# 103: decl_name > 1.2549999952316284
# 103: if_condition_expr_operator > 13.050000190734863
# 103: decl_name <= 1.2949999570846558
# 103: expr_call_argument_expr_name > 3.5149999856948853
# 103: if_condition_expr_operator <= 14.050000190734863
# 103: expr_call_argument_expr_name <= 5.184999942779541
# 103: expr_name <= 9.490000247955322
# 103: expr_operator <= 0.29999999701976776
# 103: expr_operator > 20.55500030517578
# 103: expr_operator > 0.14000000059604645
# 103: expr_name > 10.704999923706055
# 103: if_condition_expr_operator <= 13.039999961853027
# 103: expr_operator > 7.440000057220459
# 103: expr_name <= 3.174999952316284
# 103: expr_operator > 22.329999923706055
# 102: decl_name <= 15.454999923706055
# 102: expr_call_argument_expr_name <= 6.070000171661377
# 102: if_condition_expr_operator <= 8.304999828338623
# 102: decl_name <= 1.9800000190734863
# 102: decl_name > 0.1250000037252903
# 102: decl_name > 1.675000011920929
# 102: expr_call_argument_expr_name > 0.7150000035762787
# 102: expr_call_name > 11.619999885559082
# 102: decl_name <= 7.115000009536743
# 101: expr_operator <= 10.369999885559082
# 101: expr_call_name > 0.6699999868869781
# 101: expr_call_name <= 9.980000019073486
# 101: decl_name <= -3.649999976158142
# 100: decl_name > 8.454999923706055
# 100: expr_call_name <= 8.625
# 100: expr_name <= 16.5
# 100: if_condition_expr_operator > 9.804999828338623
# 100: expr_call_argument_expr_name <= 2.4250000715255737
# 99: expr_operator > 0.29999999701976776
# 99: decl_name <= 15.309999942779541
# 99: expr_call_argument_expr_name <= 6.025000095367432
# 99: decl_name > -0.3149999976158142
# 99: expr_name > -3.0
# 99: expr_call_argument_expr_name > 6.629999876022339
# 99: if_condition_expr_operator > 7.669999837875366
# 99: expr_operator > 1.5699999928474426
# 99: expr_call_name <= 12.440000057220459
# 99: decl_name > 6.559999942779541
# 99: decl_name <= 14.365000247955322
# 99: expr_operator > -3.7950000762939453
# 99: if_condition_expr_operator > 11.619999885559082
# 98: if_condition_expr_operator <= 3.1049998998641968
# 98: decl_name > 8.400000095367432
# 97: expr_call_argument_expr_name > 5.565000057220459
# 97: expr_call_argument_expr_name <= 0.5849999785423279
# 97: expr_call_argument_expr_name > 0.9699999988079071
# 97: expr_operator > -21.600000381469727
# 97: expr_operator > 0.4099999964237213
# 97: expr_name <= 8.204999923706055
# 97: expr_call_name > -1.9649999737739563
# 97: decl_name > 22.41999912261963
# 96: expr_call_argument_expr_name > 6.5
# 96: expr_call_name <= 8.349999904632568
# 95: expr_call_name > 4.690000057220459
# 95: decl_name > 21.225000381469727
# 94: decl_name > 0.3349999934434891
# 94: if_condition_expr_operator > 11.724999904632568
# 94: if_condition_expr_operator <= 14.475000381469727
# 94: expr_call_name <= 9.945000171661377
# 94: if_condition_expr_operator > 14.565000057220459
# 93: expr_call_argument_expr_name > -2.8299999237060547
# 93: decl_name <= 2.34499990940094
# 93: expr_name <= 8.235000133514404
# 93: expr_call_argument_expr_name <= 1.074999988079071
# 93: decl_name <= 15.065000057220459
# 93: decl_name > 1.5850000381469727
# 93: expr_call_argument_expr_name > 0.5149999856948853
# 93: if_condition_expr_operator > 18.015000343322754
# 92: if_condition_expr_operator > 1.4649999737739563
# 92: decl_name <= 8.25
# 92: decl_name <= 17.55500030517578
# 92: if_condition_expr_operator <= 12.15500020980835
# 92: if_condition_expr_operator > 6.289999961853027
# 92: if_condition_expr_operator <= 6.9599997997283936
# 92: decl_name > 6.5950000286102295
# 92: expr_call_name <= 4.0350000858306885
# 92: if_condition_expr_operator > 10.519999980926514
# 92: decl_name <= -6.495000123977661
# 92: if_condition_expr_operator <= 17.354999542236328
# 92: expr_name > 3.5149999856948853
# 92: expr_call_argument_expr_name > 0.574999988079071
# 92: expr_call_argument_expr_name <= 7.369999885559082
# 92: decl_name <= 13.630000114440918
# 92: expr_call_name <= 11.634999752044678
# 92: expr_name <= 15.40500020980835
# 92: expr_call_name <= 19.59000015258789
# 92: expr_call_argument_expr_name <= 6.2850000858306885
# 92: decl_name > 1.2649999856948853
# 92: decl_name > 6.0950000286102295
# 92: expr_call_argument_expr_name <= 0.9449999928474426
# 92: decl_name <= 8.934999942779541
# 92: expr_operator <= 0.1899999976158142
# 92: expr_call_argument_expr_name <= 6.019999980926514
# 92: decl_name <= 13.445000171661377
# 92: if_condition_expr_operator > 14.605000019073486
# 92: decl_name > -3.649999976158142
# 92: expr_operator <= 2.965000033378601
# 92: expr_operator <= 30.40499973297119
# 92: expr_name > -0.11999999918043613
# 92: expr_call_argument_expr_name > 0.510000005364418
# 92: expr_call_argument_expr_name > 5.680000066757202
# 92: if_condition_expr_operator > 5.490000009536743
# 92: decl_name > 1.8050000071525574
# 92: expr_call_name > -1.3300000429153442
# 91: expr_call_argument_expr_name > 1.1949999928474426
# 91: decl_name <= 12.860000133514404
# 91: if_condition_expr_operator <= 10.519999980926514
# 91: expr_operator <= 0.14500000327825546
# 91: expr_call_name <= 14.720000267028809
# 91: if_condition_expr_operator <= 6.005000114440918
# 90: decl_name > 1.6349999904632568
# 90: decl_name > 6.930000066757202
# 90: decl_name <= 14.690000057220459
# 89: decl_name > 14.565000057220459
# 89: expr_call_argument_expr_name > 5.5950000286102295
# 89: expr_call_name > 12.825000286102295
# 88: expr_call_argument_expr_name <= 6.440000057220459
# 88: if_condition_expr_operator <= 10.605000019073486
# 88: expr_name > -3.384999990463257
# 88: expr_name > -7.2799999713897705
# 88: decl_name > 15.389999866485596
# 88: if_condition_expr_operator <= 14.84000015258789
# 88: expr_name > 7.235000133514404
# 88: if_condition_expr_operator <= 14.320000171661377
# 88: expr_operator > 0.06000000052154064
# 88: expr_operator <= 35.084999084472656
# 87: decl_name > -6.360000133514404
# 87: if_condition_expr_operator <= 14.605000019073486
# 87: expr_call_name > 16.640000343322754
# 87: expr_call_argument_expr_name > 7.3399999141693115
# 87: if_condition_expr_operator > 6.355000019073486
# 87: if_condition_expr_operator > 4.315000057220459
# 86: decl_name <= 16.210000038146973
# 86: expr_operator <= 2.7350000143051147
# 86: expr_operator <= 21.394999504089355
# 86: decl_name <= 1.2049999833106995
# 86: expr_name <= 5.065000057220459
# 86: if_condition_expr_operator <= 13.065000057220459
# 86: expr_call_argument_expr_name > -1.1299999952316284
# 86: expr_name <= 7.115000009536743
# 86: decl_name <= 14.565000057220459
# 86: expr_call_argument_expr_name > 1.5149999856948853
# 86: if_condition_expr_operator > 6.015000104904175
# 86: decl_name > 15.570000171661377
# 86: if_condition_expr_operator > 8.625
# 86: expr_call_argument_expr_name > 1.1050000190734863
# 86: expr_call_argument_expr_name > 5.265000104904175
# 86: if_condition_expr_operator <= 9.055000305175781
# 86: decl_name <= 1.5600000023841858
# 85: decl_name > 1.4149999618530273
# 85: decl_name > 14.300000190734863
# 85: decl_name > 6.4100000858306885
# 85: expr_call_name > 15.03000020980835
# 84: expr_call_name > 4.525000095367432
# 84: decl_name <= 1.840000033378601
# 84: decl_name > 10.875
# 84: decl_name <= 14.699999809265137
# 84: if_condition_expr_operator <= 5.065000057220459
# 84: expr_call_argument_expr_name <= 0.5850000083446503
# 84: expr_operator > 6.644999980926514
# 84: if_condition_expr_operator <= -1.7549999952316284
# 84: expr_call_argument_expr_name > 0.375
# 84: decl_name > 13.429999828338623
# 83: expr_name > 2.915000081062317
# 83: expr_call_argument_expr_name <= 4.055000066757202
# 83: expr_name <= 6.690000057220459
# 83: decl_name > 7.06000018119812
# 82: expr_call_argument_expr_name <= 0.41499999165534973
# 81: if_condition_expr_operator <= 9.005000114440918
# 80: expr_call_argument_expr_name <= 7.860000133514404
# 80: expr_call_argument_expr_name <= 0.5300000011920929
# 80: if_condition_expr_operator > 8.190000057220459
# 80: expr_operator > 0.4449999928474426
# 80: decl_name <= 1.8050000071525574
# 80: decl_name > 1.600000023841858
# 79: expr_operator > 1.475000023841858
# 79: expr_operator <= 2.5999999046325684
# 79: expr_operator > 0.044999999925494194
# 79: decl_name <= 1.574999988079071
# 79: decl_name <= 7.950000047683716
# 78: if_condition_expr_operator <= -0.7050000131130219
# 77: expr_call_argument_expr_name > 6.6600000858306885
# 77: if_condition_expr_operator <= 14.46500015258789
# 77: expr_call_argument_expr_name <= 0.7250000238418579
# 77: expr_name > -2.9100000858306885
# 77: expr_operator > 25.519999504089355
# 77: decl_name > 6.069999933242798
# 76: if_condition_expr_operator > 16.899999618530273
# 76: expr_call_name > 9.934999942779541
# 75: expr_call_name > 1.1050000190734863
# 74: if_condition_expr_operator > 8.005000114440918
# 74: expr_call_argument_expr_name <= 0.5149999856948853
# 74: if_condition_expr_operator > 14.315000057220459
# 74: expr_call_argument_expr_name > 4.684999942779541
# 74: expr_operator > -20.21500015258789
# 74: if_condition_expr_operator <= 8.950000286102295
# 74: decl_name <= 2.659999966621399
# 74: expr_call_argument_expr_name > 0.5150000154972076
# 74: expr_name <= -0.11999999918043613
# 74: expr_name > 8.204999923706055
# 73: expr_call_argument_expr_name <= 6.924999952316284
# 73: if_condition_expr_operator <= 18.394999504089355
# 72: expr_call_argument_expr_name <= 0.48000000417232513
# 71: expr_operator <= 0.5299999862909317
# 46: decl_name <= 1.6349999904632568
# 40: expr_name > -8.359999895095825
# 36: expr_operator > 17.890000343322754
# 36: expr_name <= 7.069999933242798
# 35: if_condition_expr_operator > 8.204999923706055
# 34: expr_operator > 1.5149999856948853
# 33: decl_name > 1.7199999690055847
# 33: decl_name > 6.4750001430511475
# 32: decl_name > 15.460000038146973
# 31: expr_call_name <= -3.1600000858306885
# 31: if_condition_expr_operator > 5.019999980926514
# 28: decl_name > 1.7649999856948853
# 28: expr_call_argument_expr_name <= 5.7200000286102295
# 28: expr_call_argument_expr_name > 7.365000009536743
# 28: expr_call_argument_expr_name > 5.275000095367432
# 27: if_condition_expr_operator > 14.514999866485596
# 26: expr_call_name > 12.684999942779541
# 26: if_condition_expr_operator <= -0.9749999940395355
# 26: expr_operator > 0.47999998927116394
# 26: expr_operator > 2.3550000190734863
# 26: expr_call_name > 11.775000095367432
# 25: expr_call_argument_expr_name <= 5.990000009536743
# 25: decl_name <= 10.305000305175781
# 25: expr_call_name > 10.099999904632568
# 24: expr_call_argument_expr_name > 0.009999999776482582
# 24: expr_call_argument_expr_name > 1.1299999952316284
# 24: expr_operator > 6.650000095367432
# 24: decl_name <= 13.40999984741211
# 24: expr_operator <= 26.4350004196167
# 24: expr_operator > 8.40500020980835
# 22: decl_name > 6.009999990463257
# 22: decl_name > 1.2950000166893005
# 22: expr_call_argument_expr_name <= 5.5950000286102295
# 22: expr_call_argument_expr_name <= 7.234999895095825
# 22: expr_call_name <= 1.034999966621399
# 22: expr_name <= 12.690000057220459
# 21: decl_name <= 1.5899999737739563
# 21: if_condition_expr_operator > 9.005000114440918
# 20: expr_call_argument_expr_name <= 6.015000104904175
# 20: if_condition_expr_operator > 14.540000438690186
# 20: expr_call_argument_expr_name <= -3.4950000047683716
# 20: decl_name <= -0.8550000190734863
# 20: expr_call_argument_expr_name <= -3.3949999809265137
# 20: if_condition_expr_operator > 6.585000038146973
# 20: expr_call_argument_expr_name <= 6.130000114440918
# 20: decl_name > 1.840000033378601
# 19: expr_operator > 0.2900000065565109
# 19: if_condition_expr_operator > 8.139999866485596
# 19: expr_call_name > 0.6700000166893005
# 19: expr_name > -9.639999866485596
# 19: decl_name <= 1.5950000286102295
# 19: expr_call_argument_expr_name <= 0.574999988079071
# 19: expr_call_name <= 13.925000190734863
# 19: decl_name <= 6.919999837875366
# 19: expr_call_argument_expr_name > 0.6650000214576721
# 19: expr_call_argument_expr_name <= 0.04499999899417162
# 19: decl_name <= 14.559999942779541
# 19: expr_name > -7.425000190734863
# 19: if_condition_expr_operator > 14.475000381469727
# 19: if_condition_expr_operator <= 16.565000534057617
# 19: if_condition_expr_operator <= 14.360000133514404
# 19: decl_name > 9.115000247955322
# 19: decl_name > 9.105000019073486
# 18: expr_name > 3.8149999380111694
# 18: if_condition_expr_operator > 14.28000020980835
# 18: decl_name > -0.39000000059604645
# 18: expr_call_name > 5.144999980926514
# 18: if_condition_expr_operator > -0.9749999940395355
# 18: expr_call_name <= 15.37000036239624
# 17: expr_call_name > 0.6650000214576721
# 17: expr_operator > 9.315000057220459
# 17: expr_call_name <= 9.934999942779541
# 17: expr_call_name <= 15.369999885559082
# 17: decl_name > 1.574999988079071
# 16: expr_call_argument_expr_name > 6.019999980926514
# 16: if_condition_expr_operator <= 0.4400000050663948
# 16: expr_call_argument_expr_name <= -4.0899999141693115
# 15: decl_name > 1.550000011920929
# 15: if_condition_expr_operator > 0.4400000050663948
# 15: expr_operator > 23.020000457763672
# 15: expr_call_name > 0.4650000035762787
# 15: expr_call_argument_expr_name <= 0.9399999976158142
# 15: expr_call_argument_expr_name <= 6.769999980926514
# 15: expr_call_argument_expr_name > 0.014999999664723873
# 15: expr_name > 3.740000009536743
# 15: expr_operator <= 5.4700000286102295
# 15: expr_call_name <= 0.8650000095367432
# 15: expr_operator > -7.5950000286102295
# 15: decl_name <= 5.615000009536743
# 14: expr_name <= 0.8849999904632568
# 14: expr_call_name <= 2.2450000047683716
# 14: decl_name > 7.255000114440918
# 14: expr_call_argument_expr_name <= 0.48999999463558197
# 14: decl_name <= 15.400000095367432
# 14: if_condition_expr_operator <= -0.5300000160932541
# 14: decl_name > 1.6649999618530273
# 14: expr_call_argument_expr_name > 6.769999980926514
# 14: expr_call_name <= 12.684999942779541
# 13: expr_call_name > 0.4749999940395355
# 13: expr_operator <= 6.4649999141693115
# 13: expr_call_argument_expr_name > 5.569999933242798
# 13: expr_call_argument_expr_name > 0.5649999976158142
# 13: decl_name > 1.2099999785423279
# 13: decl_name <= 2.534999966621399
# 13: decl_name > 1.5849999785423279
# 13: decl_name > 6.799999952316284
# 13: if_condition_expr_operator > 7.025000095367432
# 13: decl_name > 14.490000247955322
# 13: expr_operator <= -7.799999952316284
# 13: expr_call_name > -3.1600000858306885
# 13: expr_name <= 0.004999999888241291
# 13: decl_name > 1.875
# 13: expr_name > 2.365000009536743
# 13: expr_call_name <= 12.429999828338623
# 13: expr_operator > 1.8300000429153442
# 13: decl_name <= 10.945000171661377
# 13: decl_name > 1.1150000095367432
# 13: if_condition_expr_operator <= 5.2850000858306885
# 13: if_condition_expr_operator <= 15.184999942779541
# 13: if_condition_expr_operator > 2.5200001001358032
# 13: if_condition_expr_operator > 5.004999876022339
# 13: if_condition_expr_operator <= -1.9449999928474426
# 13: if_condition_expr_operator <= 6.200000047683716
# 13: expr_call_argument_expr_name <= 1.9900000095367432
# 13: expr_operator > 1.5600000023841858
# 13: expr_call_name <= 15.934999465942383
# 13: if_condition_expr_operator <= 17.0
# 13: expr_operator > 19.645000457763672
# 13: expr_call_name <= 8.40500020980835
# 13: if_condition_expr_operator <= 14.805000305175781
# 12: expr_operator <= 6.670000076293945
# 12: decl_name > 11.800000190734863
# 12: decl_name > 8.115000247955322
# 12: expr_operator <= 22.050000190734863
# 12: expr_call_name <= -1.9000000357627869
# 12: decl_name <= 16.260000228881836
# 12: expr_operator > 1.1600000262260437
# 12: decl_name <= 1.600000023841858
# 12: decl_name > 2.559999942779541
# 12: expr_name > 7.059999942779541
# 12: expr_call_argument_expr_name > 0.5200000107288361
# 12: if_condition_expr_operator <= 5.014999866485596
# 12: decl_name > 14.699999809265137
# 12: decl_name > 1.64000004529953
# 12: expr_operator <= 2.700000047683716
# 12: expr_operator <= 1.5600000023841858
# 12: if_condition_expr_operator > 6.909999847412109
# 12: expr_call_argument_expr_name <= 2.5299999713897705
# 11: decl_name <= 15.420000076293945
# 11: decl_name > 5.799999952316284
# 11: expr_name <= 4.715000152587891
# 11: decl_name > 1.9399999976158142
# 11: if_condition_expr_operator > 5.7200000286102295
# 11: expr_call_name <= 0.4650000035762787
# 11: expr_call_argument_expr_name <= 0.32999999821186066
# 11: if_condition_expr_operator > 8.21999979019165
# 11: if_condition_expr_operator <= 14.510000228881836
# 11: expr_call_name > 0.945000022649765
# 11: if_condition_expr_operator > 14.449999809265137
# 11: if_condition_expr_operator > 7.664999961853027
# 11: expr_call_argument_expr_name <= 0.4599999934434891
# 11: expr_operator <= 7.359999895095825
# 11: expr_call_name > 0.5249999761581421
# 11: expr_call_name > 12.345000267028809
# 11: expr_call_name <= 14.119999885559082
# 10: expr_call_name <= 0.6700000166893005
# 10: decl_name > 1.8250000476837158
# 10: expr_call_argument_expr_name <= 6.4100000858306885
# 10: decl_name <= 16.309999465942383
# 10: if_condition_expr_operator <= 13.360000133514404
# 10: decl_name <= 14.945000171661377
# 10: decl_name <= 14.345000267028809
# 10: if_condition_expr_operator > 2.825000047683716
# 10: if_condition_expr_operator > 18.394999504089355
# 10: expr_call_name > 0.48499999940395355
# 10: decl_name <= 1.2400000095367432
# 10: decl_name > 11.315000057220459
# 9: decl_name <= 8.190000057220459
# 9: if_condition_expr_operator <= 14.78499984741211
# 9: expr_call_name <= 0.7300000190734863
# 9: if_condition_expr_operator <= 7.920000076293945
# 9: expr_name <= 2.1850000619888306
# 9: expr_call_argument_expr_name <= 0.014999999664723873
# 9: if_condition_expr_operator > 5.109999895095825
# 9: expr_call_name <= 2.0049999952316284
# 9: expr_operator > -20.190000534057617
# 9: expr_name <= -0.9199999868869781
# 9: if_condition_expr_operator <= 7.325000047683716
# 9: decl_name <= 17.52500057220459
# 9: decl_name > 1.4300000071525574
# 9: expr_name <= 6.789999961853027
# 8: expr_name > -8.785000324249268
# 8: if_condition_expr_operator <= 8.96999979019165
# 8: if_condition_expr_operator > 5.2850000858306885
# 8: expr_call_argument_expr_name > -1.8300000429153442
# 8: if_condition_expr_operator > 6.9599997997283936
# 8: expr_operator <= -0.7549999952316284
# 8: expr_call_argument_expr_name <= 0.5799999833106995
# 8: expr_operator <= 2.7050000429153442
# 8: expr_name > 0.5300000011920929
# 8: expr_name <= -8.359999895095825
# 8: expr_call_name > 0.39499999582767487
# 8: decl_name <= 14.170000076293945
# 8: decl_name <= 15.460000038146973
# 8: decl_name > 1.975000023841858
# 8: expr_operator <= -0.9099999964237213
# 8: expr_name > 4.684999942779541
# 8: if_condition_expr_operator > 7.724999904632568
# 8: decl_name <= 2.559999942779541
# 8: decl_name > 1.9350000023841858
# 8: expr_call_name > -1.5699999928474426
# 8: expr_operator <= 0.044999999925494194
# 8: expr_call_name <= 9.829999923706055
# 8: expr_call_argument_expr_name > 1.5199999809265137
# 8: expr_call_argument_expr_name <= 5.049999952316284
# 8: expr_name > 0.29999999701976776
# 8: expr_name > 6.059999942779541
# 8: expr_operator > 1.375
# 8: decl_name <= 16.1899995803833
# 8: expr_name <= 5.909999847412109
# 7: expr_operator > 1.324999988079071
# 7: if_condition_expr_operator > 0.20000000298023224
# 7: expr_call_argument_expr_name > 1.3100000023841858
# 7: decl_name > 1.2200000286102295
# 7: decl_name > 3.4550000429153442
# 7: expr_name > 5.909999847412109
# 7: if_condition_expr_operator > 5.5299999713897705
# 7: decl_name <= -6.009999990463257
# 7: expr_call_name <= 13.700000286102295
# 7: expr_operator <= 0.4099999964237213
# 7: expr_operator <= 5.494999885559082
# 7: expr_operator <= 0.47999998927116394
# 7: decl_name <= 1.975000023841858
# 7: if_condition_expr_operator <= 8.445000171661377
# 7: expr_call_name > 12.429999828338623
# 7: expr_call_argument_expr_name > 5.3450000286102295
# 7: expr_operator <= 1.5649999976158142
# 7: expr_operator > 5.805000066757202
# 7: expr_name > -0.8199999928474426
# 7: expr_call_name > 7.419999837875366
# 7: decl_name > 6.169999837875366
# 7: decl_name <= 9.75
# 7: expr_call_argument_expr_name > 0.41499999165534973
# 7: expr_operator <= 6.525000095367432
# 7: expr_call_argument_expr_name > 0.5799999833106995
# 7: expr_call_argument_expr_name > 5.190000057220459
# 7: if_condition_expr_operator > 5.034999847412109
# 7: expr_operator <= 5.460000038146973
# 7: expr_operator <= 20.369999885559082
# 7: decl_name > 2.659999966621399
# 6: expr_name > 14.635000228881836
# 6: expr_operator <= 16.920000076293945
# 6: if_condition_expr_operator <= 6.3500001430511475
# 6: if_condition_expr_operator > 10.599999904632568
# 6: expr_operator <= 1.8149999976158142
# 6: if_condition_expr_operator > 14.320000171661377
# 6: if_condition_expr_operator <= 14.480000019073486
# 6: expr_call_argument_expr_name <= 0.5349999964237213
# 6: if_condition_expr_operator > 7.375
# 6: expr_call_name <= 16.40999984741211
# 6: expr_operator <= 24.354999542236328
# 6: decl_name <= 1.25
# 6: decl_name <= 15.389999866485596
# 6: decl_name <= 8.46500015258789
# 6: expr_call_name <= 11.544999599456787
# 6: expr_call_argument_expr_name <= 0.375
# 6: expr_call_argument_expr_name > 1.1100000143051147
# 6: expr_call_argument_expr_name > -5.130000114440918
# 6: decl_name > -3.9799998998641968
# 6: expr_operator > 1.409999966621399
# 6: decl_name > 3.024999976158142
# 6: if_condition_expr_operator <= 3.424999952316284
# 6: decl_name > 1.7450000047683716
# 6: decl_name <= 1.7300000190734863
# 6: expr_operator <= 1.274999976158142
# 6: expr_call_name <= -1.3300000429153442
# 6: expr_operator <= -5.365000009536743
# 6: expr_call_argument_expr_name <= 0.15000000596046448
# 6: expr_operator <= 7.18500018119812
# 6: expr_operator > 30.40499973297119
# 6: if_condition_expr_operator > 2.5950000286102295
# 5: decl_name <= 2.7049999237060547
# 5: if_condition_expr_operator <= 8.114999771118164
# 5: expr_operator <= 1.649999976158142
# 5: expr_operator > 0.5049999952316284
# 5: decl_name > 0.5099999904632568
# 5: decl_name <= 1.550000011920929
# 5: expr_call_argument_expr_name > 0.5099999904632568
# 5: decl_name > -6.430000066757202
# 5: expr_operator > 0.4300000071525574
# 5: decl_name <= 1.9550000429153442
# 5: if_condition_expr_operator <= 6.355000019073486
# 5: expr_operator <= -8.239999771118164
# 5: decl_name <= 13.494999885559082
# 5: decl_name > -3.3000000715255737
# 5: if_condition_expr_operator > 10.605000019073486
# 5: decl_name > 6.4649999141693115
# 5: expr_call_argument_expr_name > -1.524999976158142
# 5: decl_name <= 6.169999837875366
# 5: if_condition_expr_operator <= 13.650000095367432
# 5: decl_name <= 11.039999961853027
# 5: decl_name <= 14.095000267028809
# 5: expr_call_name <= 0.009999999776482582
# 5: expr_call_argument_expr_name > 8.050000190734863
# 5: if_condition_expr_operator > 8.989999771118164
# 5: expr_call_name <= 11.110000133514404
# 5: expr_call_name > 4.664999961853027
# 5: if_condition_expr_operator > 0.36499999463558197
# 5: expr_call_name > 10.449999809265137
# 5: if_condition_expr_operator > 8.150000095367432
# 5: decl_name <= 10.489999771118164
# 5: expr_call_name > 10.649999618530273
# 5: expr_call_name <= 11.929999828338623
# 5: expr_operator <= 2.9450000524520874
# 5: expr_call_name > 0.7649999856948853
# 5: decl_name > 1.0600000023841858
# 5: expr_call_argument_expr_name > 6.515000104904175
# 5: expr_call_name <= 12.519999980926514
# 5: expr_call_name <= 19.375
# 5: expr_operator > -1.899999976158142
# 5: decl_name > 14.184999942779541
# 5: expr_operator > 0.32999999821186066
# 5: expr_operator > 0.04500000178813934
# 5: expr_operator > 17.960000038146973
# 5: if_condition_expr_operator > 6.3500001430511475
# 5: expr_call_argument_expr_name <= 6.424999952316284
# 5: expr_operator <= 20.55500030517578
# 5: expr_call_name > 12.59000015258789
# 5: expr_name <= 3.4550000429153442
# 5: expr_call_argument_expr_name <= 7.8450000286102295
# 5: expr_call_argument_expr_name > 7.304999828338623
# 5: expr_call_name > -1.4049999713897705
# 5: if_condition_expr_operator <= 5.0950000286102295
# 5: if_condition_expr_operator > 2.680000066757202
# 5: expr_call_name > 4.009999990463257
# 5: expr_operator <= 0.23499999940395355
# 5: decl_name <= 13.695000171661377
# 5: expr_call_name <= 9.994999885559082
# 5: expr_call_name <= 13.960000038146973
# 4: decl_name > -7.019999980926514
# 4: decl_name <= -3.340000033378601
# 4: expr_name <= 6.390000104904175
# 4: decl_name > 3.0299999713897705
# 4: decl_name > 1.7350000143051147
# 4: decl_name <= 13.275000095367432
# 4: expr_name > 8.49500036239624
# 4: decl_name > 1.5450000166893005
# 4: expr_operator > 1.090000033378601
# 4: expr_operator <= -3.6449999809265137
# 4: if_condition_expr_operator <= 10.914999961853027
# 4: expr_call_name <= 0.48499999940395355
# 4: expr_call_argument_expr_name > 5.184999942779541
# 4: decl_name > 1.274999976158142
# 4: expr_call_argument_expr_name > -3.4950000047683716
# 4: decl_name > 0.3050000071525574
# 4: decl_name > 0.6399999856948853
# 4: expr_operator > -0.9099999964237213
# 4: expr_call_argument_expr_name <= 2.534999966621399
# 4: decl_name > 1.6449999809265137
# 4: expr_operator <= -4.289999961853027
# 4: expr_call_name <= 11.775000095367432
# 4: decl_name <= 9.355000019073486
# 4: expr_operator > 5.315000057220459
# 4: expr_name > 6.390000104904175
# 4: decl_name > 5.539999961853027
# 4: expr_operator <= 0.5499999821186066
# 4: expr_call_argument_expr_name <= 0.7899999916553497
# 4: expr_call_name > -3.115000009536743
# 4: if_condition_expr_operator <= 8.525000095367432
# 4: if_condition_expr_operator > 6.2149999141693115
# 4: decl_name > 25.399999618530273
# 4: decl_name <= 1.7649999856948853
# 4: expr_call_argument_expr_name <= 5.565000057220459
# 4: expr_call_name > 15.309999942779541
# 4: decl_name <= 6.234999895095825
# 4: decl_name > 2.7450000047683716
# 4: expr_operator > 0.06500000134110451
# 4: decl_name > 1.5899999737739563
# 4: if_condition_expr_operator > 0.6650000065565109
# 4: expr_name > 2.534999966621399
# 4: expr_name > -6.684999942779541
# 4: expr_call_name > 10.03499984741211
# 4: if_condition_expr_operator <= 0.4050000011920929
# 4: expr_call_name > 11.46999979019165
# 4: if_condition_expr_operator > 13.065000057220459
# 4: decl_name > 14.470000267028809
# 4: expr_call_argument_expr_name > 0.6150000095367432
# 4: expr_call_name > 4.8450000286102295
# 4: decl_name <= 14.269999980926514
# 4: if_condition_expr_operator <= 14.449999809265137
# 4: expr_operator > -0.33500000834465027
# 3: expr_call_argument_expr_name > 0.019999999552965164
# 3: expr_name <= 1.4700000286102295
# 3: if_condition_expr_operator <= 6.865000009536743
# 3: decl_name <= -6.430000066757202
# 3: decl_name > 1.25
# 3: expr_call_name <= 12.345000267028809
# 3: expr_operator > 1.6299999952316284
# 3: expr_operator <= 5.974999904632568
# 3: expr_operator <= 29.8149995803833
# 3: expr_call_name > 15.934999465942383
# 3: expr_call_argument_expr_name > 7.119999885559082
# 3: expr_name <= 12.704999923706055
# 3: expr_name <= 7.1650002002716064
# 3: decl_name > 1.2350000143051147
# 3: expr_operator > 18.05500030517578
# 3: expr_call_name > 13.355000019073486
# 3: if_condition_expr_operator <= 14.769999980926514
# 3: expr_call_name > 4.674999952316284
# 3: decl_name > 21.005000114440918
# 3: decl_name > 2.490000009536743
# 3: expr_call_argument_expr_name > 0.5049999952316284
# 3: expr_operator <= 7.440000057220459
# 3: decl_name <= 6.390000104904175
# 3: decl_name <= 1.5850000381469727
# 3: decl_name > 14.569999694824219
# 3: if_condition_expr_operator <= 7.1600000858306885
# 3: expr_operator > 5.4700000286102295
# 3: if_condition_expr_operator > 14.039999961853027
# 3: if_condition_expr_operator > 13.360000133514404
# 3: if_condition_expr_operator <= 16.97499942779541
# 3: if_condition_expr_operator > 14.454999923706055
# 3: expr_call_argument_expr_name <= 7.174999952316284
# 3: if_condition_expr_operator <= 2.099999964237213
# 3: decl_name > 10.429999828338623
# 3: if_condition_expr_operator <= 14.375
# 3: expr_call_argument_expr_name > 0.5849999785423279
# 3: decl_name <= 1.274999976158142
# 2: decl_name <= 1.7199999690055847
# 2: expr_call_name <= 11.015000343322754
# 2: expr_name <= 1.0149999856948853
# 2: expr_call_name <= 11.349999904632568
# 2: expr_call_name > 5.115000009536743
# 2: expr_call_name <= 8.96999979019165
# 2: decl_name <= 4.840000152587891
# 2: expr_operator <= 0.4750000089406967
# 2: decl_name > -2.049999952316284
# 2: expr_call_name > 10.119999885559082
# 2: expr_operator <= 1.5149999856948853
# 2: expr_name > -0.08999999798834324
# 2: expr_operator <= 6.644999980926514
# 2: expr_name > -7.450000047683716
# 2: if_condition_expr_operator <= -2.134999990463257
# 2: decl_name > 0.47999998927116394
# 2: if_condition_expr_operator > 13.630000114440918
# 2: if_condition_expr_operator <= 7.1499998569488525
# 2: if_condition_expr_operator <= 7.669999837875366
# 2: decl_name <= 5.8349997997283936
# 2: if_condition_expr_operator > 6.629999876022339
# 2: expr_name <= 7.125
# 2: decl_name > 9.62999963760376
# 2: expr_operator > 6.4750001430511475
# 2: expr_operator <= 9.570000171661377
# 2: expr_call_argument_expr_name > 0.004999999888241291
# 2: decl_name <= 12.595000267028809
# 2: if_condition_expr_operator <= 1.73499995470047
# 2: expr_name <= 12.865000247955322
# 2: expr_call_argument_expr_name > 7.509999990463257
# 2: expr_call_name <= 2.4450000524520874
# 2: expr_name > 5.629999876022339
# 2: decl_name > -4.144999980926514
# 2: expr_call_argument_expr_name > 2.069999933242798
# 2: expr_call_argument_expr_name <= 7.229999780654907
# 2: expr_call_argument_expr_name > 1.5350000262260437
# 2: decl_name > 14.589999675750732
# 2: expr_call_argument_expr_name > 0.39000000059604645
# 2: expr_call_name > 12.40999984741211
# 2: expr_name <= 7.235000133514404
# 2: expr_call_name > 10.614999771118164
# 2: expr_operator <= -4.090000152587891
# 2: expr_name > 9.150000095367432
# 2: expr_call_name > 0.925000011920929
# 2: expr_operator > 16.920000076293945
# 2: if_condition_expr_operator <= 10.224999904632568
# 2: if_condition_expr_operator > 5.065000057220459
# 2: decl_name <= 6.799999952316284
# 2: if_condition_expr_operator > 1.7850000262260437
# 2: expr_operator > -19.6850004196167
# 2: decl_name <= 16.179999351501465
# 2: expr_operator > 20.369999885559082
# 2: decl_name > 1.3300000429153442
# 2: expr_call_argument_expr_name <= 6.490000009536743
# 2: if_condition_expr_operator > 7.325000047683716
# 2: expr_name > 14.724999904632568
# 2: if_condition_expr_operator <= 14.454999923706055
# 2: expr_name > 9.275000095367432
# 2: expr_call_argument_expr_name > 2.9450000524520874
# 2: expr_operator <= 2.3499999046325684
# 2: expr_operator <= 4.710000038146973
# 2: expr_name <= 3.165000081062317
# 2: expr_call_argument_expr_name <= 1.3100000023841858
# 2: decl_name > 11.184999942779541
# 2: if_condition_expr_operator > 8.75
# 2: expr_operator <= 1.4850000143051147
# 2: decl_name <= 2.1750000715255737
# 2: decl_name <= 10.429999828338623
# 2: decl_name > 2.1850000619888306
# 2: expr_call_argument_expr_name > 0.5850000083446503
# 2: expr_call_argument_expr_name <= 0.7350000143051147
# 2: expr_operator <= 0.3799999952316284
# 2: decl_name > 6.919999837875366
# 2: expr_operator > 3.7350000143051147
# 1: decl_name > 1.7800000309944153
# 1: decl_name <= 25.399999618530273
# 1: expr_call_argument_expr_name <= 0.16499999910593033
# 1: decl_name <= 1.5550000071525574
# 1: expr_call_argument_expr_name > 7.174999952316284
# 1: if_condition_expr_operator > 6.974999904632568
# 1: decl_name <= 1.6449999809265137
# 1: expr_operator <= 0.255000002682209
# 1: if_condition_expr_operator <= 14.070000171661377
# 1: decl_name > 6.495000123977661
# 1: if_condition_expr_operator > 8.525000095367432
# 1: expr_name <= 7.034999847412109
# 1: if_condition_expr_operator <= 8.295000076293945
# 1: expr_operator > 0.14500000327825546
# 1: expr_call_argument_expr_name > 0.5300000011920929
# 1: expr_name <= 7.0950000286102295
# 1: if_condition_expr_operator <= 7.5299999713897705
# 1: decl_name > 5.9649999141693115
# 1: decl_name <= 14.59499979019165
# 1: decl_name <= 1.4149999618530273
# 1: decl_name <= 2.430000066757202
# 1: if_condition_expr_operator > 3.975000023841858
# 1: if_condition_expr_operator > 4.230000019073486
# 1: decl_name > 2.34499990940094
# 1: expr_name > -3.4950000047683716
# 1: expr_name <= 2.534999966621399
# 1: rule
# 1: decl_name > 5.769999980926514
# 1: decl_name > 4.355000019073486
# 1: decl_name <= 1.5350000262260437
# 1: expr_name <= -1.7149999737739563
# 1: decl_name <= 1.7350000143051147
# 1: expr_operator > 3.0199999809265137
# 1: decl_name > 8.570000171661377
# 1: expr_call_argument_expr_name > -2.4550000429153442
# 1: expr_operator > 2.200000047683716
# 1: decl_name <= 14.599999904632568
# 1: expr_operator > 26.824999809265137
# 1: decl_name > 13.880000114440918
# 1: decl_name <= 14.40999984741211
# 1: if_condition_expr_operator <= 17.265000343322754
# 1: expr_operator <= 22.38499927520752
# 1: if_condition_expr_operator <= -0.23000001907348633
# 1: if_condition_expr_operator <= -1.7350000143051147
# 1: if_condition_expr_operator <= 6.0350000858306885
# 1: if_condition_expr_operator > 9.450000286102295
# 1: expr_call_argument_expr_name <= -1.1299999952316284
# 1: expr_operator > 5.494999885559082
# 1: decl_name > 1.5999999642372131
# 1: expr_name <= 5.5950000286102295
# 1: decl_name <= 6.559999942779541
# 1: decl_name > 1.6549999713897705
# 1: expr_call_argument_expr_name <= 5.765000104904175
# 1: if_condition_expr_operator > 15.434999942779541
# 1: expr_call_argument_expr_name > 5.945000171661377
