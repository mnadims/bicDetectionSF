# %%
"""
@author: mdn769@usask.ca

'''
This will first generate the commit pattern files after reading the XML file generated by srcML tool. 
Then it will convert those commit patterns to GML graph representation. 
'''
"""
import xml.etree.ElementTree as ET
from IPython.display import clear_output
import os

import networkx as nx
#import matplotlib.pyplot as plt

from collections import Counter
import pandas as pd

# %%
G = nx.MultiDiGraph()
patterns=[]
def print_path(n, val=""):   
    str_val=str(n.tag).replace("{http://www.srcML.org/srcML/src}","").replace("{http://www.srcML.org/srcML/cpp}","")
    val+="-"+str_val
    length=len(n)
    #print(length, str_val)
    if(length>0):
        for x in n:
            print_path(x, val)
    elif(len(val)>0): 
        newVal = val.replace("decl_stmt-decl-", "decl-").replace(
            "argument_list-argument-", "argument-").replace(
            "expr_stmt-expr-", "expr-").replace(
            "parameter_list-parameter-", "parameter-").replace(
            "block-block_content-", "block-").replace(
            "if_stmt-if-", "if-").replace(
            "-empty_stmt", "")
        
        patterns.append(newVal) #remove unwanted patterns
        
        
def generate_graph(patterns):
    G.clear()
    node_list=[]    
    for cp in patterns:
        path=cp[1:].split('-') #First position has unnecessary '-'
        for n in path:
            if(n not in node_list):
                G.add_node(n) #Add unique nodes. 
        for i in range(0, len(path)-1):
            #print(path[i], "-->", path[i+1])
            if(G.has_edge(path[i], path[i+1]) == False):
                G.add_edge(path[i], path[i+1])     
    return G

# %%
file_path = "C:/Users/mdn769/BugFixStatistics/SCGrunable/runable/"

# %%
''' This will find a list of unique patterns (TP Features) from all the files in this subject system. Each item of the list will be
the feature name of the dataset to be prepared. 
'''
list_pattern = []
count = 0
inPath = file_path+ "source_xml/qtbase/added/"
for file in os.listdir(inPath):   
    if(count == 100):
        break
    #print(inPath+file)
    if(file[-4:]==".xml"):
        #print("Working for: "+ss+", "+ctype+", "+file)    
        try:
            tree = ET.parse(inPath+file)
            root = tree.getroot()
            patterns=[]
            for n in root:
                print_path(n)

            #print(len(patterns))
            for p in patterns:
                if p[1:] not in list_pattern:
                    list_pattern.append(p[1:]) #dont take the first character '-'
                    
        except: not_worked += ss+", "+ctype+", "+file+"\n"

    count+=1

print(len(list_pattern))
# Out:
# 4628

# %%
''' This will find a list of unique token sequences (TS Features) from all the files in this subject system. Each item of the list will be
the feature name of the dataset to be prepared. 
'''
list_sequence = []
count = 0
inPath = file_path+ "source_xml/qtbase/added/"
for file in os.listdir(inPath):   
    if(count == 5):
        break
    #print(inPath+file)
    if(file[-4:]==".xml"):
        #print("Working for: "+ss+", "+ctype+", "+file)    
        try:
            tree = ET.parse(inPath+file)
            root = tree.getroot()
            patterns=[]
            for n in root:
                print_path(n)

            #print(len(patterns))
            file_tokens = []
            for p in patterns:
                for t in p.split('-'):
                    if(len(t)>0):
                        file_tokens.append(t)
                    
        except: not_worked += ss+", "+ctype+", "+file+"\n"

    count+=1
    
ngram = 3
temp=zip(*[file_tokens[i:] for i in range(0, ngram)]) #n-gram = 3
ans=[' '.join(ngram) for ngram in temp]

print(list(set(ans)))
# Out:
# ['condition decl init', 'init expr call', 'directive ifndef directive', 'argument expr name', 'name endif directive', 'endif directive ifndef', 'type name if', 'type modifier if', 'condition decl name', 'if block if', 'condition expr name', 'if condition expr', 'name name if', 'block expr call', 'name name endif', 'name if block', 'expr literal if', 'call argument_list if', 'expr call argument', 'call name operator', 'argument_list if block', 'file endif directive', 'expr call name', 'expr call argument_list', 'directive include file', 'call argument expr', 'condition decl type', 'literal if block', 'name if condition', 'block if block', 'decl init expr', 'decl type name', 'call name name', 'block if condition', 'ifndef name include', 'if condition decl', 'expr name if', 'name operator if', 'argument expr literal', 'ifndef name if', 'directive ifndef name', 'expr name name', 'decl type modifier', 'name include directive', 'modifier if block', 'include file endif', 'operator if block', 'decl name if', 'include directive include', 'if block expr', 'expr name operator', 'ifndef directive ifndef']

# %%
for p in list_pattern:
    print(p)
# Out:
# decl-type-specifier
# decl-type-name
# decl-name
# decl-init-expr-call-name
# decl-init-expr-call-argument_list
# if-condition-expr-name
# if-condition-expr-operator
# if-block-block_content
# include-directive
# include-file
# decl-argument-expr-name
# decl-init-expr-literal
# decl-type-modifier
# decl-init-expr-call-name-name
# decl-init-expr-call-name-operator
# if-condition-expr-call-name
# if-condition-expr-call-argument-expr-call-name-name
# if-condition-expr-call-argument-expr-call-name-operator
# if-condition-expr-call-argument-expr-call-argument_list
# if-condition-expr-call-argument-expr-literal
# if-block-expr-call-name
# if-block-expr-call-argument-expr-name
# if-directive
# if-expr-call-name
# if-expr-call-argument-expr-name
# if-expr-operator
# ifndef-directive
# ifndef-name
# endif-directive
# function_decl-type-specifier
# function_decl-type-name
# function_decl-name
# function_decl-parameter-decl-type-specifier
# function_decl-parameter-decl-type-name
# function_decl-parameter-decl-type-modifier
# function_decl-parameter-decl-name
# function_decl-parameter-decl-type-name-name
# function_decl-parameter-decl-type-name-operator
# comment
# decl-name-name
# decl-name-operator
# decl-argument-expr-specifier
# decl-argument-expr-operator
# decl-argument-expr-name-name
# decl-argument-expr-name-operator
# if-condition-expr-name-name
# if-condition-expr-name-operator
# if-block-decl-type-name
# if-block-decl-type-modifier
# if-block-decl-name
# if-block-decl-init-expr-cast-argument-expr-name
# if-block-decl-init-expr-cast-argument-expr-operator
# if-block-decl-init-expr-cast-argument-expr-call-name-name
# if-block-decl-init-expr-cast-argument-expr-call-name-operator
# if-block-decl-init-expr-cast-argument-expr-call-argument_list
# if-block-if-condition-expr-call-name-name
# if-block-if-condition-expr-call-name-operator
# if-block-if-condition-expr-call-argument-expr-name-name
# if-block-if-condition-expr-call-argument-expr-name-operator
# if-block-if-block-decl-type-name
# if-block-if-block-decl-name
# if-block-if-block-while-condition-expr-call-name
# if-block-if-block-while-condition-expr-call-argument-expr-operator
# if-block-if-block-while-condition-expr-call-argument-expr-name
# if-block-if-block-while-condition-expr-call-argument-expr-call-name-name
# if-block-if-block-while-condition-expr-call-argument-expr-call-name-operator
# if-block-if-block-while-condition-expr-call-argument-expr-call-argument_list
# if-block-if-block-while-block
# if-block-if-block-expr-call-name-name
# if-block-if-block-expr-call-name-operator
# if-block-if-block-expr-call-argument-expr-name-name
# if-block-if-block-expr-call-argument-expr-name-operator
# if-block-if-block-return-expr-literal
# decl-argument_list-return-expr-literal
# case-expr-name-name
# case-expr-name-operator
# return-expr-literal
# expr-literal
# decl-argument-expr-call-name
# decl-argument-expr-call-argument-expr-name-name
# decl-argument-expr-call-argument-expr-name-operator
# decl-argument-expr-call-argument-expr-name
# expr-call-name
# expr-call-argument_list
# expr-call-argument-expr-name-name
# expr-call-argument-expr-name-operator
# expr-call-argument-expr-name
# expr-call-argument-expr-call-name
# expr-call-argument-expr-call-argument-expr-name
# expr-call-argument-expr-literal
# expr-name
# expr-operator
# expr_stmt-operator
# expr-specifier
# expr-macro-name
# expr-macro-argument_list-argument
# ifdef-directive
# ifdef-name
# function_decl-name-name
# function_decl-name-operator
# function_decl-decl-type-specifier
# function_decl-decl-type-name
# function_decl-decl-name
# if-condition-expr-call-argument_list
# if-condition-expr-call-argument-expr-name
# if-block-return-expr-literal
# expr-name-name
# expr-name-operator
# decl-init-expr-operator
# decl-init-expr-name
# decl-init-expr-call-argument-expr-name
# expr-name-index-expr-literal
# expr-call-name-name
# expr-call-name-operator
# decl-init-expr-name-name
# decl-init-expr-name-operator
# if-block-expr-name-name
# if-block-expr-name-operator
# if-block-expr-name-index-expr-literal
# if-block-expr-operator
# if-block-expr-ternary-condition-expr-name
# if-block-expr-ternary-then-expr-literal
# if-block-expr-ternary-else-expr-literal
# if_stmt-comment
# if_stmt-else-block-expr-name-name
# if_stmt-else-block-expr-name-operator
# if_stmt-else-block-expr-name-index-expr-literal
# if_stmt-else-block-expr-operator
# if_stmt-else-block-expr-ternary-condition-expr-name
# if_stmt-else-block-expr-ternary-then-expr-literal
# if_stmt-else-block-expr-ternary-else-expr-literal
# expr-call-argument-expr-call-name-name
# expr-call-argument-expr-call-name-operator
# expr-call-argument-expr-call-argument_list
# expr-call-argument-expr-operator
# constructor-name-name
# constructor-name-operator
# constructor-parameter_list
# constructor-member_init_list-call-name
# constructor-member_init_list-call-argument-expr-literal
# constructor-member_init_list-call-name-name
# constructor-member_init_list-call-name-operator
# constructor-member_init_list-call-argument-expr-operator
# constructor-member_init_list-call-argument-expr-call-name-name
# constructor-member_init_list-call-argument-expr-call-name-operator
# constructor-member_init_list-call-argument-expr-call-argument_list
# constructor-member_init_list-call-argument-expr-call-argument-expr-name-name
# constructor-member_init_list-call-argument-expr-call-argument-expr-name-operator
# constructor-member_init_list-call-argument-expr-block-expr-name
# constructor-member_init_list-call-argument-expr-block-expr-operator
# constructor-member_init_list-call-argument-expr-block-expr-call-name-name
# constructor-member_init_list-call-argument-expr-block-expr-call-name-operator
# constructor-member_init_list-call-argument-expr-block-expr-call-argument_list
# constructor-member_init_list-call-argument-expr-block-expr-call-name
# constructor-member_init_list-call-argument-expr-block-expr-specifier
# constructor-member_init_list-call-argument-expr-block-expr-call-argument-expr-name
# constructor-member_init_list-call-argument-expr-block-expr-call-argument-expr-call-name-name
# constructor-member_init_list-call-argument-expr-block-expr-call-argument-expr-call-name-operator
# constructor-member_init_list-call-argument-expr-block-expr-call-argument-expr-call-argument_list
# constructor-member_init_list-call-argument-expr-block-expr-name-name
# constructor-member_init_list-call-argument-expr-block-expr-name-operator
# constructor-member_init_list-call-argument-expr-block-expr-call-argument-expr-name-name
# constructor-member_init_list-call-argument-expr-block-expr-call-argument-expr-name-operator
# constructor-member_init_list-call-argument-expr-block-if-condition-expr-name-name
# constructor-member_init_list-call-argument-expr-block-if-condition-expr-name-operator
# constructor-member_init_list-call-argument-expr-block-if-block-expr-call-name
# constructor-member_init_list-call-argument-expr-block-if-block-expr-call-argument-expr-name
# constructor-member_init_list-call-argument_list-if-condition-expr-call-name-name
# constructor-member_init_list-call-argument_list-if-condition-expr-call-name-operator
# constructor-member_init_list-call-argument_list-if-condition-expr-call-argument_list
# constructor-member_init_list-call-argument_list-if-condition-expr-operator
# constructor-member_init_list-call-argument_list-if-condition-expr-name-name
# constructor-member_init_list-call-argument_list-if-condition-expr-name-operator
# constructor-member_init_list-call-argument_list-if-expr-block
# if-block-if-condition-decl-type-name
# if-block-if-condition-decl-type-modifier
# if-block-if-condition-decl-name
# if-block-if-condition-decl-init-expr-call-name-name
# if-block-if-condition-decl-init-expr-call-name-operator
# if-block-if-condition-decl-init-expr-call-argument_list
# if-block-if-block-expr-call-argument-expr-name
# if-block-if-block-expr-call-argument-expr-literal
# class-name
# class-block-private
# class-block-public-typedef-type-name-name
# class-block-public-typedef-type-name-argument-expr-name
# class-block-public-typedef-name
# class-block-public-comment
# class-block-public-typedef-type-name-operator
# class-block-public-function-type-name-name
# class-block-public-function-type-name-operator
# class-block-public-function-name
# class-block-public-function-parameter_list
# class-block-public-function-specifier
# class-block-public-function-block-return-expr-call-name-name
# class-block-public-function-block-return-expr-call-name-operator
# class-block-public-function-block-return-expr-call-argument_list
# class-block-public-constructor-name
# class-block-public-constructor-parameter_list
# class-block-public-constructor-member_init_list-call-name
# class-block-public-constructor-member_init_list-call-argument-expr-literal
# class-block-public-constructor-block-block_content
# class-block-public-function-type-name
# class-block-public-function-parameter-decl-type-specifier
# class-block-public-function-parameter-decl-type-name
# class-block-public-function-parameter-decl-type-modifier
# class-block-public-function-parameter-decl-name
# class-block-public-function-block-decl-type-name-name
# class-block-public-function-block-decl-type-name-operator
# class-block-public-function-block-decl-name
# class-block-public-function-block-decl-init-expr-call-name-name
# class-block-public-function-block-decl-init-expr-call-name-operator
# class-block-public-function-block-decl-init-expr-call-argument-expr-name
# class-block-public-function-block-if-condition-expr-name
# class-block-public-function-block-if-condition-expr-operator
# class-block-public-function-block-if-condition-expr-call-name-name
# class-block-public-function-block-if-condition-expr-call-name-operator
# class-block-public-function-block-if-condition-expr-call-argument_list
# class-block-public-function-block-if-block-return-expr-call-name-name
# class-block-public-function-block-if-block-return-expr-call-name-operator
# class-block-public-function-block-if-block-return-expr-call-argument_list
# class-block-public-function-block-decl-type-name
# class-block-public-function-block-decl-init-expr-name
# class-block-public-function-block-expr-call-name-name
# class-block-public-function-block-expr-call-name-operator
# class-block-public-function-block-expr-call-argument-expr-name
# class-block-public-function-block-expr-name
# class-block-public-function-block-expr-operator
# class-block-public-function-block-expr-call-argument_list
# class-block-public-function-block-expr-literal
# class-block-public-function-block-return-expr-name
# class-block-private-decl-type-name
# class-block-private-decl-name
# expr-name-index-expr-name
# expr-name-index-expr-operator
# decl-init-expr-name-index-expr-call-name-name
# decl-init-expr-name-index-expr-call-name-operator
# decl-init-expr-name-index-expr-call-argument_list
# block-decl-type-name-name
# block-decl-type-name-operator
# block-decl-name
# block-for-control-init-expr-name
# block-for-control-init-expr-operator
# block-for-control-init-expr-call-name-name
# block-for-control-init-expr-call-name-operator
# block-for-control-init-expr-call-argument_list
# block-for-control-condition-expr-name
# block-for-control-condition-expr-operator
# block-for-control-condition-expr-call-name-name
# block-for-control-condition-expr-call-name-operator
# block-for-control-condition-expr-call-argument_list
# block-for-control-incr-expr-operator
# block-for-control-incr-expr-name
# block-for-block-expr-call-name
# block-for-block-expr-call-argument-expr-name
# block-for-block-expr-call-argument-expr-operator
# block-for-block-expr-call-argument-expr-call-name-name
# block-for-block-expr-call-argument-expr-call-name-operator
# block-for-block-expr-call-argument-expr-call-argument_list
# block-for-block-expr-call-argument-expr-call-name
# block-for-block-expr-name-name
# block-for-block-expr-name-index-expr-call-name-name
# block-for-block-expr-name-index-expr-call-name-operator
# block-for-block-expr-name-index-expr-call-argument_list
# block-for-block-expr-name-index-expr-operator
# block-for-block-expr-name-index-expr-call-name
# block-for-block-expr-operator
# block-for-block-expr-literal
# if-block-break
# decl-argument-expr-literal
# class_decl-name
# macro-name
# typedef-type-name-name
# typedef-type-name-argument-expr-name
# typedef-name
# decl-range-expr-name
# decl-range-expr-operator
# macro-argument_list-argument
# expr-name-argument-expr-name
# decl-range-expr-name-name
# decl-range-expr-name-argument-expr-name
# function_decl-type-modifier
# function_decl-parameter_list
# expr-cast-argument-expr-specifier
# expr-cast-argument-expr-name
# expr-cast-argument-expr-operator
# return-expr-call-name-name
# return-expr-call-name-operator
# return-expr-call-argument-expr-name
# return-expr-call-argument-expr-name-name
# return-expr-call-argument-expr-name-operator
# return-expr-call-argument-expr-name-index-expr-name
# expr-index
# expr-cast-argument-expr-name-name
# expr-cast-argument-expr-name-operator
# decl-init-expr-ternary-condition-expr-call-name
# decl-init-expr-ternary-condition-expr-call-argument_list
# decl-init-expr-ternary-then-expr-literal
# decl-init-expr-ternary-else-expr-literal
# expr-call-name-argument-expr-name-name
# expr-call-name-argument-expr-name-argument-expr-name
# decl-type-name-name
# decl-type-name-argument-expr-name
# if-condition-expr-call-name-name
# if-condition-expr-call-name-operator
# if-condition-expr-call-name-argument-expr-name
# if-block-decl-init-expr-call-name-name
# if-block-decl-init-expr-call-name-operator
# if-block-decl-init-expr-call-name-argument-expr-name
# if-block-decl-init-expr-call-argument_list
# if-block-foreach-control-init-decl-type-specifier
# if-block-foreach-control-init-decl-type-name
# if-block-foreach-control-init-decl-type-modifier
# if-block-foreach-control-init-decl-name
# if-block-foreach-control-init-decl-range-expr-name
# if-block-foreach-block-expr-call-name
# if-block-foreach-block-expr-call-argument_list
# if-block-foreach-block-expr-operator
# if-block-foreach-block-expr-name
# if-block-for-control-init-decl-type-specifier
# if-block-for-control-init-decl-type-name
# if-block-for-control-init-decl-type-modifier
# if-block-for-control-init-decl-name
# if-block-for-control-init-decl-range-expr-name
# if-block-for-block-expr-call-name
# if-block-for-block-expr-call-argument_list
# if-block-for-block-expr-operator
# if-block-for-block-expr-name
# if-block-decl-type-name-name
# if-block-decl-type-name-operator
# if-block-decl-type-specifier
# if-block-for-control-init
# if-block-for-control-condition-expr-name
# if-block-for-control-condition-expr-operator
# if-block-for-control-incr-expr-operator
# if-block-for-control-incr-expr-name
# if-block-comment
# if-block-ifndef-directive
# if-block-ifndef-name
# if-block-template-parameter-type-name
# if-block-template-parameter-name
# if-block-template-friend-function_decl-type-name
# if-block-template-friend-function_decl-name
# if-block-template-friend-function_decl-parameter_list
# if-block-endif-directive
# if-block-else-directive
# if-block-public-endif-directive
# if-block-private-macro-name
# if-block-private-macro-argument_list-argument
# if-block-private-operator
# if-block-private-block-block_content
# if-block-private-decl-type-specifier
# if-block-private-decl-type-name
# if-block-private-decl-name
# if-block-private-decl-type-modifier
#
# function-template-parameter-type-name
# function-template-parameter-name
# function-type-name-name
# function-type-specifier
# function-type-name
# function-name
# function-parameter-decl-type-name
# function-parameter-decl-type-modifier
# function-parameter-decl-name
# function-block-expr-operator
# function-block-expr-name
# function-block-expr-call-name
# function-block-expr-call-argument-expr-name
# function-block-decl-type-name
# function-block-decl-type-modifier
# function-block-decl-name
# function-block-decl-init-expr-operator
# function-block-decl-init-expr-cast-argument-expr-name
# function-block-decl-init-expr-cast-argument-expr-operator
# function-block-expr-call-name-name
# function-block-expr-call-name-operator
# function-block-expr-cast-argument-expr-name
# function-block-expr-cast-argument-expr-operator
# function-type-modifier
# function-parameter-decl-type-specifier
# function-block-return-expr-operator
# function-block-return-expr-cast-argument-expr-name
# function-block-return-expr-cast-argument-expr-operator
# function-block-return-expr-name
# function-type-name-name-name
# function-type-name-name-argument-expr-specifier
# function-type-name-name-argument-expr-name
# function-type-name-name-argument-expr-operator
# function-block-block_content
# decl-type
# struct_decl-template-parameter-type-name
# struct_decl-template-parameter-name
# struct_decl-template-parameter-init-expr-name-name
# struct_decl-template-parameter-init-expr-name-operator
# struct_decl-template-parameter-init-expr-name-argument-expr-name-name
# struct_decl-template-parameter-init-expr-name-argument-expr-name-operator
# struct_decl-name
# struct-template-parameter-type-name
# struct-template-parameter-name
# struct-name-name
# struct-name-argument-expr-name
# struct-name-argument-expr-name-name
# struct-name-argument-expr-name-operator
# struct-block-public-enum-block-decl-name
# struct-block-public-enum-block-decl-init-expr-name
# struct-block-public-enum-block-decl-init-expr-operator
# function-name-name
# function-name-argument-expr-name
# function-specifier
# function-block-return-expr-call-name-name
# function-block-return-expr-call-name-operator
# function-block-return-expr-call-argument-expr-call-name-name
# function-block-return-expr-call-argument-expr-call-name-operator
# function-block-return-expr-call-argument-expr-call-argument_list
# struct-name-argument-expr-name-argument-expr-name
# struct-super_list-super-name-name
# struct-super_list-super-name-argument-expr-name-name
# struct-super_list-super-name-argument-expr-name-argument-expr-name
# struct-block-public-function-type-specifier
# struct-block-public-function-type-name
# struct-block-public-function-name
# struct-block-public-function-parameter-decl-type-specifier
# struct-block-public-function-parameter-decl-type-name-name
# struct-block-public-function-parameter-decl-type-name-argument-expr-name
# struct-block-public-function-parameter-decl-type-modifier
# struct-block-public-function-parameter-decl-name
# struct-block-public-function-block-return-expr-call-name-name
# struct-block-public-function-block-return-expr-call-name-operator
# struct-block-public-function-block-return-expr-call-argument_list
# struct-super_list-super-name-argument-expr-name-operator
# struct-block-public-function-parameter-decl-type-name-operator
# macro
# public-decl-type-specifier
# public-decl-type-name
# public-decl-type-modifier
# public-decl-name
# public-typedef-function_decl-type-name
# public-typedef-function_decl-modifier
# public-typedef-function_decl-name
# public-typedef-function_decl-parameter-decl-type-specifier
# public-typedef-function_decl-parameter-decl-type-name
# public-typedef-function_decl-parameter-decl-type-modifier
# public-typedef-function_decl-parameter-decl-name
# public-typedef-function_decl-type-specifier
# public-typedef-function_decl-type-modifier
# public-function-template-parameter-type-name
# public-function-template-parameter-name
# public-function-type-specifier
# public-function-type-name
# public-function-name
# public-function-parameter-decl-type-specifier
# public-function-parameter-decl-type-name
# public-function-parameter-decl-type-modifier
# public-function-parameter-decl-name
# public-function-block-return-expr-call-name-name-name
# public-function-block-return-expr-call-name-name-argument-expr-name
# public-function-block-return-expr-call-name-operator
# public-function-block-return-expr-call-name-name
# public-function-block-return-expr-call-argument-expr-cast-argument-expr-specifier
# public-function-block-return-expr-call-argument-expr-cast-argument-expr-name
# public-function-block-return-expr-call-argument-expr-cast-argument-expr-operator
# public-function-type-modifier
# public-function-block-decl-type-name-typename
# public-function-block-decl-type-name-name
# public-function-block-decl-type-name-operator
# public-function-block-decl-name
# public-function-block-decl-init-expr-cast-argument-expr-specifier
# public-function-block-decl-init-expr-cast-argument-expr-name
# public-function-block-decl-init-expr-cast-argument-expr-operator
# public-function-block-decl-init-expr-operator
# public-function-block-decl-init-expr-call-name
# public-function-block-decl-init-expr-call-argument_list
# public-function-block-expr-call-name-name
# public-function-block-expr-call-name-operator
# public-function-block-expr-call-argument-expr-name
# public-function-block-return-expr-call-name-name-argument-expr-name-typename
# public-function-block-return-expr-call-name-name-argument-expr-name-name
# public-function-block-return-expr-call-name-name-argument-expr-name-operator
# public-function-block-return-expr-call-argument-expr-name
# public-function-block-expr-call-name-name-name
# public-function-block-expr-call-name-name-argument-expr-name-typename
# public-function-block-expr-call-name-name-argument-expr-name-name
# public-function-block-expr-call-name-name-argument-expr-name-operator
# public-function-block-expr-call-argument-expr-cast-argument-expr-specifier
# public-function-block-expr-call-argument-expr-cast-argument-expr-name
# public-function-block-expr-call-argument-expr-cast-argument-expr-operator
# public-function-block-expr-call-argument-expr-operator
# public-function-block-expr-call-argument-expr-call-name
# public-function-block-expr-call-argument-expr-call-argument_list
# public-function-block-return-expr-operator
# public-function-block-return-expr-cast-argument-expr-name-typename
# public-function-block-return-expr-cast-argument-expr-name-name
# public-function-block-return-expr-cast-argument-expr-name-operator
# public-function-block-return-expr-cast-argument-expr-operator
# public-function-block-return-expr-cast-argument-expr-name
# public-function-block-return-expr-call-name
# public-function-block-return-expr-call-argument-expr-call-name-name-name
# public-function-block-return-expr-call-argument-expr-call-name-name-argument-expr-name-typename
# public-function-block-return-expr-call-argument-expr-call-name-name-argument-expr-name-name
# public-function-block-return-expr-call-argument-expr-call-name-name-argument-expr-name-operator
# public-function-block-return-expr-call-argument-expr-call-name-operator
# public-function-block-return-expr-call-argument-expr-call-name-name
# public-function-block-return-expr-call-argument-expr-call-argument-expr-name
# public-template-parameter-type-name
# public-template-parameter-name
# public-template-constructor-name
# public-template-constructor-parameter-decl-type-specifier
# public-template-constructor-parameter-decl-type-name
# public-template-constructor-parameter-decl-type-modifier
# public-template-constructor-parameter-decl-name
# public-template-constructor-member_init_list-call-name
# public-template-constructor-member_init_list-call-argument-expr-name
# public-template-constructor-member_init_list-call-argument-expr-literal
# public-template-constructor-member_init_list-call-argument-expr-call-name-name
# public-template-constructor-member_init_list-call-argument-expr-call-name-argument-expr-name-typename
# public-template-constructor-member_init_list-call-argument-expr-call-name-argument-expr-name-name
# public-template-constructor-member_init_list-call-argument-expr-call-name-argument-expr-name-operator
# public-template-constructor-member_init_list-call-argument-expr-call-argument_list
# public-template-constructor-member_init_list-call-argument-expr-name-name-name
# public-template-constructor-member_init_list-call-argument-expr-name-name-argument-expr-name-typename
# public-template-constructor-member_init_list-call-argument-expr-name-name-argument-expr-name-name
# public-template-constructor-member_init_list-call-argument-expr-name-name-argument-expr-name-operator
# public-template-constructor-member_init_list-call-argument-expr-name-operator
# public-template-constructor-member_init_list-call-argument-expr-name-name
# public-template-constructor-member_init_list-call-argument-expr-name-name-argument-expr-name
# public-template-constructor-member_init_list-call-argument-expr-name-argument-expr-name
# public-template-constructor-block-block_content
# public-macro-name
# public-macro-argument_list
# public-macro-argument-literal
# public-operator
# public-macro-argument_list-argument
# public-block-block_content
# public-function-parameter_list
# public-function-block-expr-call-name
# public-function-specifier
# public-function-block-return-expr-call-argument-expr-operator
# public-function-block-return-expr-call-argument-expr-name-name
# public-function-block-return-expr-call-argument-expr-name-operator
# public-function-block-expr-call-argument-expr-literal
# public-function-block-return-expr-name
# public-function-block-return-expr-call-argument-expr-call-name
# function-block-return-expr-call-name
# function-block-return-expr-call-argument-expr-operator
# function-block-return-expr-call-argument-expr-name
# decl-type-ifndef-directive
# decl-type-ifndef-name
# decl-type-name-typename
# decl-endif-directive
# decl-name-name-name
# decl-name-name-argument-expr-name-typename
# decl-name-name-argument-expr-name-name
# decl-name-name-argument-expr-name-operator
# decl-init-expr-call-name-argument-expr-name
# decl-init-expr-call-name-argument-expr-name-name
# decl-init-expr-call-name-argument-expr-name-operator
# decl-type-name-operator
# return-expr-call-argument-expr-operator
# return-expr-call-argument-expr-call-name-name
# return-expr-call-argument-expr-call-name-operator
# return-expr-call-argument-expr-call-name-argument-expr-name
# return-expr-call-argument-expr-call-name-argument-expr-name-name
# return-expr-call-argument-expr-call-name-argument-expr-name-operator
# return-expr-call-argument-expr-call-name-argument-expr-name-argument-expr-name
# return-expr-call-argument-expr-call-argument-expr-name
# decl-range-expr-name-operator
# decl-range-expr-literal
# decl-argument_list
# decl-argument-expr-call-name-name
# decl-argument-expr-call-name-operator
# decl-argument-expr-call-argument-expr-call-name-name
# decl-argument-expr-call-argument-expr-call-name-argument-expr-name-name
# decl-argument-expr-call-argument-expr-call-name-argument-expr-name-operator
# decl-argument-expr-call-argument-expr-call-argument_list
# decl-comment
# decl-include-directive
# decl-include-file
# public-struct-name
# public-struct-block-public
# public-struct-block-private-decl-type-name-name
# public-struct-block-private-decl-type-name-operator
# public-struct-block-private-decl-name
# public-struct-block-private-decl-type-name
# public-struct-block-private-decl-type-modifier
# public-struct-block-private-friend-class_decl-name
# public-struct-block-private-expr-specifier
# public-struct-block-private-expr-call-name
# public-struct-block-private-expr-call-argument-expr-specifier
# public-struct-block-private-expr-call-argument-expr-name
# public-struct-block-private-expr-call-argument-expr-operator
# public-struct-block-private-expr-operator
# public-struct-block-private-expr-call-argument-expr-name-name
# public-struct-block-private-expr-call-argument-expr-name-operator
# public-struct-block-private-expr_stmt-operator
# public-struct-block-private-expr_stmt-macro-name
# public-struct-block-private-expr_stmt-macro-argument_list-argument
# public-struct-block-private-expr-block-expr-call-name-name
# public-struct-block-private-expr-block-expr-call-name-operator
# public-struct-block-private-expr-block-expr-call-argument_list
# public-struct-block-private-expr-name
# public-struct-block-private-expr-macro-name
# public-struct-block-private-expr-macro-argument_list
# public-struct-block-private-expr-block-if-condition-expr-operator
# public-struct-block-private-expr-block-if-condition-expr-call-name-name
# public-struct-block-private-expr-block-if-condition-expr-call-name-operator
# public-struct-block-private-expr-block-if-condition-expr-call-argument_list
# public-struct-block-private-expr-block-if-block-expr-call-name-name
# public-struct-block-private-expr-block-if-block-expr-call-name-operator
# public-struct-block-private-expr-block-if-block-expr-call-argument_list
# public-struct-block-private-expr-block-if-block-expr_stmt
# public-struct-decl-namespace-specifier
# public-struct-decl-namespace-name
# public-struct-decl-namespace-modifier
# public-block-expr-call-name-name
# public-block-expr-call-name-operator
# public-block-expr-call-argument_list
# public-function-name-name
# public-function-block-decl-type-specifier
# public-function-block-decl-init-expr-call-name-name
# public-function-block-decl-init-expr-call-name-operator
# public-function-block-if-condition-expr-name-name
# public-function-block-if-condition-expr-name-operator
# public-function-block-if-condition-expr-operator
# public-function-block-if-condition-expr-call-name-name
# public-function-block-if-condition-expr-call-name-argument-expr-name
# public-function-block-if-condition-expr-call-argument_list
# public-function-block-if-block-return-expr-operator
# public-function-block-if-block-return-expr-cast-argument-expr-specifier
# public-function-block-if-block-return-expr-cast-argument-expr-name
# public-function-block-if-block-return-expr-cast-argument-expr-operator
# public-function-block-if-block-return-expr-cast-argument-expr-name-name
# public-function-block-if-block-return-expr-cast-argument-expr-name-operator
# public-function-block-decl-init-expr-name
# friend-struct_decl-name
# expr-block
# expr-macro-argument_list
# expr-block-expr-name
# expr-block-expr-call-name
# expr-block-expr-call-argument-expr-operator
# expr-block-expr-call-argument-expr-name
# expr-block-expr-call-argument-expr-call-name
# expr-block-expr-call-argument-expr-call-argument-expr-literal
# expr-block-expr-call-name-name
# expr-block-expr-call-name-operator
# expr-block-expr-call-argument_list
# expr-block-return-expr-name
# function-parameter_list
# function-block-decl-argument-expr-operator
# function-block-decl-argument-expr-name
# function-block-decl-argument-expr-call-name
# function-block-decl-argument-expr-call-argument-expr-literal
# function-block-expr-call-argument_list
# function-block-decl-type-specifier
# function-block-decl-type-name-name
# function-block-decl-type-name-operator
# function-block-decl-init-expr-call-name-name
# function-block-decl-init-expr-call-name-operator
# function-block-decl-init-expr-call-argument-expr-name
# function-block-if-condition-expr-name-name
# function-block-if-condition-expr-name-operator
# function-block-if-condition-expr-operator
# function-block-if-condition-expr-call-name-name
# function-block-if-condition-expr-call-name-argument-expr-name
# function-block-if-condition-expr-call-argument_list
# function-block-if-block-return-expr-operator
# function-block-if-block-return-expr-cast-argument-expr-specifier
# function-block-if-block-return-expr-cast-argument-expr-name
# function-block-if-block-return-expr-cast-argument-expr-operator
# function-block-if-block-return-expr-cast-argument-expr-name-name
# function-block-if-block-return-expr-cast-argument-expr-name-operator
# function-block-return-expr-call-argument-expr-name-name
# function-block-return-expr-call-argument-expr-name-operator
# function-block-return-expr-call-argument_list
# function-block-return-expr-name-name
# function-block-return-expr-name-operator
# struct-name
# struct-super_list-super-name-argument-expr-name
# struct-block-public
# struct-template-parameter_list
# struct-block-public-function-parameter-decl-type-name
# struct-block-public-function-block-if-condition-expr-call-name-name
# struct-block-public-function-block-if-condition-expr-call-name-operator
# struct-block-public-function-block-if-condition-expr-call-argument_list
# struct-block-public-function-block-if-condition-expr-operator
# struct-block-public-function-block-if-condition-expr-call-name-argument-expr-name
# struct-block-public-function-block-if-block-return-expr-call-name
# struct-block-public-function-block-if-block-return-expr-call-argument-expr-call-name-name
# struct-block-public-function-block-if-block-return-expr-call-argument-expr-call-name-operator
# struct-block-public-function-block-if-block-return-expr-call-argument-expr-call-argument-expr-cast-argument-expr-specifier
# struct-block-public-function-block-if-block-return-expr-call-argument-expr-call-argument-expr-cast-argument-expr-name
# struct-block-public-function-block-if-block-return-expr-call-argument-expr-call-argument-expr-cast-argument-expr-operator
# struct-block-public-function-block-if-block-return-expr-call-argument-expr-call-argument-expr-cast-argument-expr-call-name-name
# struct-block-public-function-block-if-block-return-expr-call-argument-expr-call-argument-expr-cast-argument-expr-call-name-operator
# struct-block-public-function-block-if-block-return-expr-call-argument-expr-call-argument-expr-cast-argument-expr-call-argument_list
# struct-block-public-function-block-return-expr-call-name
# struct-block-public-function-block-return-expr-call-argument-expr-call-name-name
# struct-block-public-function-block-return-expr-call-argument-expr-call-name-operator
# struct-block-public-function-block-return-expr-call-argument-expr-call-name-argument-expr-name-name
# struct-block-public-function-block-return-expr-call-argument-expr-call-name-argument-expr-name-operator
# struct-block-public-function-block-return-expr-call-argument-expr-call-argument_list
# return-expr-call-name-argument-expr-name
# function-template-parameter-init-expr-name-name
# function-template-parameter-init-expr-name-operator
# function-parameter-decl-type-name-typename
# function-parameter-decl-type-name-name
# function-parameter-decl-type-name-operator
# function-block-return-expr-call-name-argument-expr-name-typename
# function-block-return-expr-call-name-argument-expr-name-name
# function-block-return-expr-call-name-argument-expr-name-operator
# function-block-expr-call-argument-expr-call-name-name
# function-block-expr-call-argument-expr-call-name-operator
# function-block-expr-call-argument-expr-call-argument-expr-name
# function-block-return-expr-call-name-argument-expr-name
# function-type-name-name-argument-expr-name-name
# function-type-name-name-argument-expr-name-operator
# function-type-name-name-argument-expr-name-argument-expr-name
# function-parameter-decl-type-name-argument-expr-name
# function-template-parameter_list
# decl-ifdef-directive
# decl-ifdef-name
# decl-define-directive
# decl-define-macro-name
# decl-define-macro-parameter-type-name
# decl-define-value
# decl-else-directive
# decl-name-argument-expr-name-name
# decl-name-argument-expr-name-argument-expr-name
# expr-call-name-argument-expr-name-operator
# decl-modifier
# decl_stmt-operator
# block-expr-call-name-name
# block-expr-call-name-operator
# block-expr-call-argument-expr-call-name
# block-expr-call-argument-expr-call-argument-expr-literal
# block-expr-call-argument-expr-operator
# block-expr-call-argument-expr-call-argument-expr-name
# block-if-condition-expr-call-name
# block-if-condition-expr-call-argument-expr-name-name
# block-if-condition-expr-call-argument-expr-name-operator
# block-if-condition-expr-call-argument-expr-operator
# block-if-condition-expr-call-argument-expr-name
# block-if-condition-expr-call-argument-expr-call-name-name
# block-if-condition-expr-call-argument-expr-call-name-operator
# block-if-condition-expr-call-argument-expr-call-argument_list
# block-if-block-expr-call-name-name
# block-if-block-expr-call-name-operator
# block-if-block-expr-call-argument-expr-call-name
# block-if-block-expr-call-argument-expr-call-argument-expr-literal
# block-if-block-expr-call-argument-expr-operator
# block-if-block-expr-call-argument-expr-call-argument-expr-name
# block-if-block-if-condition-expr-call-name
# block-if-block-if-condition-expr-call-argument-expr-literal
# block-if-block-if-condition-expr-operator
# block-if-block-if-condition-expr-call-argument-expr-name-name
# block-if-block-if-condition-expr-call-argument-expr-name-operator
# block-if-block-if-block-expr-name
# block-if-block-if-block-expr-operator
# block-if-block-if-block-expr-call-name
# block-if-block-if-block-expr-call-argument-expr-call-name-name
# block-if-block-if-block-expr-call-argument-expr-call-name-operator
# block-if-block-if-block-expr-call-argument-expr-call-argument_list
# block-if-block-if-block-expr-call-argument-expr-name-name
# block-if-block-if-block-expr-call-argument-expr-name-operator
# block-if-block-if-block-expr-call-name-name
# block-if-block-if-block-expr-call-name-operator
# block-if-block-if-block-expr-call-argument_list
# block-if-block-if-block-expr-call-argument-expr-call-name
# block-if-block-if-block-expr-call-argument-expr-call-argument-expr-literal
# block-if-block-if-block-expr-call-argument-expr-operator
# block-if-block-if-block-expr-call-argument-expr-call-argument-expr-name
# block-if-block-if-block-decl-type-name
# block-if-block-if-block-decl-name
# block-if-block-if-block-decl-init-expr-call-name-name
# block-if-block-if-block-decl-init-expr-call-name-operator
# block-if-block-if-block-decl-init-expr-call-argument-expr-call-name
# block-if-block-if-block-decl-init-expr-call-argument-expr-call-argument-expr-literal
# block-if-block-if-block-expr-call-argument-expr-name
# block-if-block-if
# block-if-block-decl-type-name
# block-if-block-decl-type-modifier
# block-if-block-decl-name
# block-if-block-decl-init-expr-operator
# block-if-block-decl-init-expr-call-name
# block-if-block-decl-init-expr-call-argument-expr-call-name-name
# block-if-block-decl-init-expr-call-argument-expr-call-name-operator
# block-if-block-decl-init-expr-call-argument-expr-call-argument_list
# block-if-block-decl-init-expr-call-argument-expr-name-name
# block-if-block-decl-init-expr-call-argument-expr-name-operator
# block-if-block-return-expr-operator
# block-if-block-return-expr-call-name
# block-if-block-return-expr-call-argument-expr-call-name-name
# block-if-block-return-expr-call-argument-expr-call-name-operator
# block-if-block-return-expr-call-argument-expr-call-argument_list
# block-if-block-return-expr-call-argument-expr-name-name
# block-if-block-return-expr-call-argument-expr-name-operator
# block-if-block-decl-init-expr-call-name-name
# block-if-block-decl-init-expr-call-name-operator
# block-if-block-decl-init-expr-call-argument-expr-call-name
# block-if-block-decl-init-expr-call-argument-expr-call-argument-expr-literal
# block-if-block-expr-call-argument-expr-call-argument_list
# block-if-block-if-condition-expr-call-argument-expr-name
# block-if-block-if-block-return-expr-call-name
# block-if-block-if-block-return-expr-call-argument-expr-name
# block-if-block-if-block-return-expr-call-argument-expr-name-name
# block-if-block-if-block-return-expr-call-argument-expr-name-operator
# block-if-block-if-block-return-expr-call-argument-expr-literal
# block-if-block-if-block-decl-type-specifier
# block-if-block-if-block-decl-type-modifier
# block-if-block-if-block-decl-type-name-name
# block-if-block-if-block-decl-type-name-operator
# block-if-block-if-block-decl-init-expr-call-argument_list
# block-if-block-if-block-expr-name-name
# block-if-block-if-block-expr-name-operator
# block-if-block-if-block-if-condition-expr-call-name
# block-if-block-if-block-if-condition-expr-call-argument-expr-name
# block-if-block-if-block-if-block-expr-operator
# block-if-block-if-block-if-block-expr-name
# block-if-block-if-block-if-block-while-condition-expr-name
# block-if-block-if-block-if-block-while-condition-expr-operator
# block-if-block-if-block-if-block-while-condition-expr-call-name-name
# block-if-block-if-block-if-block-while-condition-expr-call-name-operator
# block-if-block-if-block-if-block-while-condition-expr-call-argument_list
# block-if-block-if-block-if-block-while-block-expr-name
# block-if-block-if-block-if-block-while-block-expr-operator
# block-if-block-if-block-if-block-while-block-expr-name-name
# block-if-block-if-block-if-block-while-block-expr-name-operator
# block-if-block-if-block-if-block-while-block-if-condition-expr-call-name
# block-if-block-if-block-if-block-while-block-if-condition-expr-call-argument-expr-name
# block-if-block-if-block-if-block-while-block-if-block-expr-operator
# block-if-block-if-block-if-block-while-block-if-block-expr-name
# block-if-block-if-block-if-block-while-block-if-block-decl-type-specifier
# block-if-block-if-block-if-block-while-block-if-block-decl-type-name
# block-if-block-if-block-if-block-while-block-if-block-decl-type-modifier
# block-if-block-if-block-if-block-while-block-if-block-decl-name
# block-if-block-if-block-if-block-while-block-if-block-decl-type
# block-if-block-if-block-if-block-while-block-if-block-decl-init-expr-name-name
# block-if-block-if-block-if-block-while-block-if-block-decl-init-expr-name-operator
# block-if-block-if-block-if-block-while-block-if-block-expr-call-name
# block-if-block-if-block-if-block-while-block-if-block-expr-call-argument-expr-call-name-name
# block-if-block-if-block-if-block-while-block-if-block-expr-call-argument-expr-call-name-operator
# block-if-block-if-block-if-block-while-block-if-block-expr-call-argument-expr-call-argument_list
# block-if-block-if-block-if-block-while-block-if-block-expr-call-argument-expr-name
# block-if-block-if-block-if-block-while-block-if-block-decl-init-expr-call-name-name
# block-if-block-if-block-if-block-while-block-if-block-decl-init-expr-call-name-operator
# block-if-block-if-block-if-block-while-block-if-block-decl-init-expr-call-argument-expr-operator
# block-if-block-if-block-if-block-while-block-if-block-decl-init-expr-call-argument-expr-name
# block-if-block-if-block-if-block-while-block-if-block-decl-type-name-name
# block-if-block-if-block-if-block-while-block-if-block-decl-type-name-operator
# block-if-block-if-block-if-block-while-block-if-block-decl-init-expr-call-argument_list
# block-if-block-if-block-if-block-while-block-if-block-decl-type-name-argument-expr-name
# block-if-block-if-block-if-block-while-block-if-block-decl-init-expr-name
# block-if-block-if-block-if-block-while-block-if-block-decl-init-expr-operator
# block-if-block-if-block-if-block-while-block-if-block-decl-init-expr-call-name
# block-if-block-if-block-if-block-while-block-if-block-decl-init-expr-call-argument-expr-literal
# block-if-block-if-block-if-block-while-block-if-block-decl-init-expr-index-expr-literal
# block-if-block-if-block-if-block-while-block-if-block-typedef-type-name-name
# block-if-block-if-block-if-block-while-block-if-block-typedef-type-name-argument-expr-name
# block-if-block-if-block-if-block-while-block-if-block-typedef-name
# block-if-block-if-block-if-block-while-block-if-block-expr-name-name
# block-if-block-if-block-if-block-while-block-if-block-expr-name-operator
# block-if-block-if-block-if-block-while-block-if-block-expr-name-index-expr-name
# block-if-block-if-block-if-block-while-block-if-block-expr-call-argument-expr-call-name
# block-if-block-if-block-if-block-while-block-if-block-expr-call-argument-expr-call-argument-expr-name
# block-if-block-if-block-if-block-while-block-if-block-expr-call-argument-expr-call-argument-expr-call-name
# block-if-block-if-block-if-block-while-block-if-block-expr-call-argument-expr-call-argument-expr-call-argument_list
# block-if-block-if-block-if-block-while-block-if-block-decl-name-name
# block-if-block-if-block-if-block-while-block-if-block-decl-name-operator
# block-if-block-if-block-if-block-while-block-if-block-decl-argument-expr-specifier
# block-if-block-if-block-if-block-while-block-if-block-decl-argument-expr-name
# block-if-block-if-block-if-block-while-block-if-block-decl-argument-expr-operator
# block-if-block-if-block-if-block-while-block-if-block-decl-modifier
# block-if-block-if-block-if-block-while-block-if-block-decl-argument_list
# block-if-block-if-block-if-block-while-block-if-block-decl-range-expr-call-name-name
# block-if-block-if-block-if-block-while-block-if-block-decl-range-expr-call-name-operator
# block-if-block-if-block-if-block-while-block-if-block-decl-range-expr-call-argument-expr-name
# block-if-block-if-block-if-block-while-block-if-block-function_decl-type-name
# block-if-block-if-block-if-block-while-block-if-block-function_decl-name
# block-if-block-if-block-if-block-while-block-if-block-function_decl-parameter-decl-type-specifier
# block-if-block-if-block-if-block-while-block-if-block-function_decl-parameter-decl-type-name
# block-if-block-if-block-if-block-while-block-if-block-function_decl-parameter-decl-type-modifier
# block-if-block-if-block-if-block-while-block-if-block-function_decl-parameter-decl-name
# block-if-block-if-block-if-block-while-block-if-block-function_decl-specifier
# block-if-block-if-block-if-block-while-block-if-block-expr-call-name-name
# block-if-block-if-block-if-block-while-block-if-block-expr-call-name-operator
# block-if-block-if-block-if-block-while-block-if-block-expr-call-argument_list
# block-if-block-if-block-if-block-while-block-if-block-expr-call-argument-expr-literal
# block-if-block-if-block-if-block-while-block-if-block-expr-index-expr-literal
# block-if-block-if-block-if-block-while-block-if-block-function_decl-type-modifier
# block-if-block-if-block-if-block-while-block-if-block-function_decl-name-name
# block-if-block-if-block-if-block-while-block-if-block-function_decl-name-operator
# block-if-block-if-block-if-block-while-block-if-block-function_decl-decl-type-name
# block-if-block-if-block-if-block-while-block-if-block-function_decl-decl-name
# block-if-block-if-block-if-block-while
# block-if-block-if-block-if-block-expr-call-name
# block-if-block-if-block-if-block-expr-call-argument-expr-call-name-name
# block-if-block-if-block-if-block-expr-call-argument-expr-call-name-operator
# block-if-block-if-block-if-block-expr-call-argument-expr-call-argument_list
# block-if-block-if-block-if-block-expr-call-argument-expr-name-name
# block-if-block-if-block-if-block-expr-call-argument-expr-name-operator
# block-if-block-if-block-if-block-expr-call-name-name
# block-if-block-if-block-if-block-expr-call-name-operator
# block-if-block-if-block-if-block-expr-call-argument-expr-name
# block-if-block-if-block-if-block-function_decl-type-name
# block-if-block-if-block-if-block-function_decl-name-name
# block-if-block-if-block-if-block-function_decl-name-operator
# block-if-block-if-block-if-block-function_decl-parameter-decl-type-specifier
# block-if-block-if-block-if-block-function_decl-parameter-decl-type-name
# block-if-block-if-block-if-block-function_decl-parameter-decl-type-modifier
# block-if-block-if-block-if-block-function_decl-parameter-decl-name
# block-if-block-if-block-if-block-function_decl-decl-type-name
# block-if-block-if-block-if-block-function_decl-decl-name
# block-if-block-function_decl-type-specifier
# block-if-block-function_decl-type-name
# block-if-block-function_decl-name
# block-if-block-function_decl-parameter-decl-type-specifier
# block-if-block-function_decl-parameter-decl-type-name
# block-if-block-function_decl-parameter-decl-type-modifier
# block-if-block-function_decl-type-modifier
# block-if-block-function_decl-parameter-decl-name
# block-if-block-decl-init-expr-name-name
# block-if-block-decl-init-expr-name-index-expr-literal
# block-if-block-if-condition-expr-call-name-name
# block-if-block-if-condition-expr-call-name-operator
# block-if-block-if-condition-expr-call-argument_list
# block-if-block-if-condition-expr-name-name
# block-if-block-if-condition-expr-name-index-expr-literal
# block-if-block-if-condition-expr-name
# block-if-block-if-block-expr-call-argument-expr-call-argument-expr-name-name
# block-if-block-if-block-expr-call-argument-expr-call-argument-expr-name-index-expr-literal
# block-if-block-if-block-expr-call-argument-expr-call-argument-expr-operator
# block-if-block-expr-call-argument-expr-name
# block-if-block-expr-call-argument-expr-name-name
# block-if-block-expr-call-argument-expr-name-operator
# block-if-block-expr-call-argument-expr-name-index-expr-literal
# block-if-block-decl-type-name-name
# block-if-block-decl-type-name-operator
# block-if-block-decl-init-expr-call-argument_list
# block-if-block-while-condition-expr-name
# block-if-block-while-condition-expr-operator
# block-if-block-while-condition-expr-call-name-name
# block-if-block-while-condition-expr-call-name-operator
# block-if-block-while-condition-expr-call-argument_list
# block-if-block-while-block-expr-call-name-name
# block-if-block-while-block-expr-call-name-operator
# block-if-block-while-block-expr-call-argument-expr-name
# block-if-block-while-block-expr-call-argument-expr-name-name
# block-if-block-while-block-expr-call-argument-expr-name-operator
# block-if-block-while-block-expr-operator
# block-if-block-while-block-expr-name
# block-if-block-while-block-decl-type-name
# block-if-block-while-block-decl-name
# block-if-block-while-block-decl-init-expr-name-name
# block-if-block-while-block-decl-init-expr-name-index-expr-literal
# block-if-block-while-block-decl-init-expr-operator
# block-if-block-while-block-decl-init-expr-name
# if-block-decl-argument-expr-call-name
# if-block-decl-argument-expr-call-argument_list
# if-block-if-condition-expr-operator
# if-block-if-condition-expr-name
# if-block-if-condition-expr-call-argument_list
# if-block-if-block-expr-name
# ...
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-if-condition-expr-call-argument-expr-operator
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-if-condition-expr-operator
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-if-condition-expr-name
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-if-block-if-condition-expr-name
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-if-block-if-block-if-condition-expr-operator
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-if-block-if-block-if-condition-expr-name
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-if-block-if-block-if-condition-expr-literal
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-if-block-if-block-if-block-expr-name
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-if-block-if-block-if-block-expr-operator
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-if-block-if-block-if-block-continue
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-if-block-if-block-if-block-return-expr-name-name
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-if-block-if-block-if-block-return-expr-name-index-expr-ternary-condition-expr-name
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-if-block-if-block-if-block-return-expr-name-index-expr-ternary-then-expr-name
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-if-block-if-block-if-block-return-expr-name-index-expr-ternary-else-expr-name
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-if-block-if-block-if-block-return-expr-name-index-expr-ternary-else-expr-operator
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-if-block-if-block-if-block-return-expr-name-index-expr-ternary-else-expr-literal
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-include-directive
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-include-file
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-function_decl-type-name
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-function_decl-name
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-function_decl-parameter-decl-type-name-name
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-function_decl-parameter-decl-type-name-operator
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-function_decl-parameter-decl-name
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-function_decl-type-name-name
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-function_decl-type-name-operator
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-function_decl-parameter_list
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-function_decl-specifier
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-function_decl-parameter-decl-type-name
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-decl-init-expr-call-name
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-decl-init-expr-call-argument_list
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-decl-init-expr-operator
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-decl-init-expr-name-name
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-decl-init-expr-name-operator
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-expr-call-name
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-expr-call-argument-expr-literal
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-expr-call-argument-expr-ternary-condition-expr-name
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-expr-call-argument-expr-ternary-then-expr-literal
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-expr-call-argument-expr-ternary-else-expr-operator
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-expr-call-argument-expr-ternary-else-expr-ternary-condition-expr-call-name
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-expr-call-argument-expr-ternary-else-expr-ternary-condition-expr-call-argument_list
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-expr-call-argument-expr-ternary-else-expr-ternary-condition-expr-operator
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-expr-call-argument-expr-ternary-else-expr-ternary-condition-expr-name-name
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-expr-call-argument-expr-ternary-else-expr-ternary-condition-expr-name-operator
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-expr-call-argument-expr-ternary-else-expr-ternary-then-expr-literal
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-expr-call-argument-expr-ternary-else-expr-ternary-else-expr-operator
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-expr-call-argument-expr-ternary-else-expr-ternary-else-expr-literal
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-expr-call-argument-expr-ternary-then-expr-operator
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-expr-call-argument-expr-ternary-else-expr-ternary-then-expr-operator
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-function-type-name-name
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-function-type-name-operator
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-function-name
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-function-parameter_list
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-function-specifier
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-function-block-return-expr-call-name-name
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-function-block-return-expr-call-name-operator
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-function-block-return-expr-call-argument_list
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-function-type-name
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-function-parameter-decl-type-name-name
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-function-parameter-decl-type-name-operator
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-function-parameter-decl-name
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-function-block-expr-call-name-name
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-function-block-expr-call-name-operator
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-function-block-expr-call-argument-expr-name
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-expr-ternary-condition-expr-call-name
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-expr-ternary-condition-expr-call-argument_list
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-expr-ternary-condition-expr-operator
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-expr-ternary-condition-expr-name-name
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-expr-ternary-condition-expr-name-operator
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-expr-ternary-then-expr-call-name-name
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-expr-ternary-then-expr-call-name-operator
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-expr-ternary-then-expr-call-argument-expr-name
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-expr-ternary-else-expr-call-name-name
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-expr-ternary-else-expr-call-name-operator
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-expr-ternary-else-expr-call-argument-expr-name
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-comment
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-decl-type-name-name
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-decl-type-name-operator
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-decl-name-name
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-decl-name-operator
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-decl-argument_list
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-decl-argument-expr-specifier
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-decl-argument-expr-name
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-return-expr-call-name-name
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-return-expr-call-name-operator
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-return-expr-call-argument_list
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-decl-argument-expr-name-name
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-decl-argument-expr-name-operator
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-expr-call-name-name
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-expr-call-name-operator
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-expr-call-argument-expr-name
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-decl-name-argument-expr-name
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-decl-argument-expr-literal
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-expr-call-name-argument-expr-name
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-decl-type-specifier
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-decl-type-modifier
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-while-condition-expr-name-name
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-while-condition-expr-name-operator
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-while-block-expr-call-argument-expr-name-name
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-while-block-expr-call-argument-expr-name-operator
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-while-block-expr-name-name
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-while-block-expr-name-operator
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-decl-init-expr-call-name-name
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-decl-init-expr-call-name-operator
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-expr-call-argument-expr-ternary-condition-expr-operator
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-expr-call-argument-expr-ternary-condition-expr-name-name
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-expr-call-argument-expr-ternary-condition-expr-name-operator
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-expr-call-argument-expr-ternary-then-expr-name-name
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-expr-call-argument-expr-ternary-then-expr-name-operator
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-expr-call-argument-expr-ternary-else-expr-name-name
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-expr-call-argument-expr-ternary-else-expr-name-operator
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-decl-type
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-decl-init-expr-literal
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-expr-call-argument_list
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-do-block-expr-name
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-do-block-expr-operator
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-do-block-expr-call-name-name
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-do-block-expr-call-name-operator
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-do-block-expr-call-argument-expr-name
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-do-block-if-condition-expr-name
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-do-block-if-condition-expr-operator
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-do-block-if-condition-expr-name-name
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-do-block-if-condition-expr-name-operator
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-do-block-if-block-expr-call-name
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-do-block-if-block-expr-call-argument-expr-name
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-do-block-if-block-expr-call-argument-expr-operator
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-do-block-if-block-expr-name
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-do-block-if-block-expr-operator
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-do-block-if-block-expr-call-name-name
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-do-block-if-block-expr-call-name-operator
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-do-block-if_stmt-else-block-expr-call-name
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-do-block-if_stmt-else-block-expr-call-argument-expr-name
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-do-block-if_stmt-else-block-expr-call-argument-expr-operator
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-do-block-if_stmt-else-block-expr-name
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-do-block-if_stmt-else-block-expr-operator
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-do-block-if_stmt-else-block-expr-call-name-name
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-do-block-if_stmt-else-block-expr-call-name-operator
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-do-condition-expr-name
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-do-block-expr-call-name
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-do-block-expr-call-argument-expr-operator
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-expr-name-name
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-expr-name-operator
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-expr-literal
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-expr-call-argument-expr-name-name
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-expr-call-argument-expr-name-operator
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-do-block-expr-call-argument-expr-name-name
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-do-block-expr-call-argument-expr-name-index-expr-name
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-do-block-if-block-expr-call-argument-expr-name-name
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-do-block-if-block-expr-call-argument-expr-name-operator
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-do-block-if_stmt-else-block-expr-call-argument-expr-name-name
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-do-block-if_stmt-else-block-expr-call-argument-expr-name-operator
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-do-block-expr-call-argument_list
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-expr-call-argument-expr-operator
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-expr-call-argument-expr-call-name-name
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-expr-call-argument-expr-call-name-operator
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-expr-call-argument-expr-call-argument_list
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-do-condition-expr-operator
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-do-condition-expr-literal
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-expr-call-argument-expr-name-argument-expr-name
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-expr-call-name-argument-expr-name-name
# if_stmt-else-block-while-block-if-block-if_stmt-else-block-expr-call-name-argument-expr-name-argument-expr-name
# if-block-decl-init-expr-call-argument-expr-call-argument_list
# if-condition-expr-name-argument-expr-literal
# if-condition-expr-name-argument-expr-operator
# if-condition-expr-name-argument-expr-name
# if-condition-expr-macro-name
# if-condition-expr-macro-argument_list-argument

# %%
#refine patterns: 
#['decl_stmt', 'argument_list', 'expr_stmt', 'parameter_list', 'block_content', 'function_decl', 'if_stmt', 'empty_stmt']
refine_arr = []
for lp in list_pattern:
    for p in lp.split('-'): 
        if('_' in p):
            if(p not in refine_arr):
                refine_arr.append(p)
                
print(refine_arr)
# Out:
# ['argument_list', 'block_content', 'function_decl', 'expr_stmt', 'if_stmt', 'parameter_list', 'member_init_list', 'class_decl', 'struct_decl', 'super_list', 'decl_stmt', 'constructor_decl', 'destructor_decl']

# %%
#Counter(list_pattern)

# %%
''' Prepare the dataset. For each commit, list_pattern is the list of feature values. 
'''
dataset = [["commit_id"] + list_pattern] # prepare the top row of the dataset. 
#subject_systems=["bitcoin", "jenkins", "litecoin", "lucene", "mongo", "oozie"]
subject_systems=["qtbase"]
#commit_type=["added", "deleted"]
commit_type=["added"]
not_worked=""
# fileContent = open("ssNames.txt", "r", encoding='utf-8').read()
# #print("Length of File Content", len(fileContent))
# ssNames = fileContent.split('\n')

for ss in subject_systems:
    if(len(ss.strip()) == 0): #Ignore the last empty line....
        break
    for ctype in commit_type:
        inPath = file_path+ "source_xml/"+ss+"/"+ctype+"/"
        #outPath = "xml_gml/"+ss+"/"+ctype+"/"
        
        count = 0
        totalFiles = len(os.listdir(inPath))
        for file in os.listdir(inPath):   
            #if(count == 10):
                #break
            #print(inPath+file)
            if(file[-4:]==".xml"):
                clear_output(wait=True)
                print("Working for: ("+str(count)+"/"+str(totalFiles)+")"+ss+", "+ctype+", "+file)    
                try:
                    tree = ET.parse(inPath+file)
                    root = tree.getroot()
                    patterns=[]
                    for n in root:
                        print_path(n)

                    countedValues = Counter(patterns)
                    
                    result_row = [file.split('.')[0]] #Take only the commit name from the file
                    ZeroLine = 0 #Checks if all the values in this row is zero
                    for lp in list_pattern:
                        tp_pattern = "-"+lp #tp starts with '-'
                        if(countedValues[tp_pattern] > 0):
                            ZeroLine += 1
                            result_row.append(countedValues[tp_pattern]) 
                        else: 
                            result_row.append(0)
                    
                    if(ZeroLine > 0):
                        dataset.append(result_row)

                except: not_worked += ss+", "+ctype+", "+file+"\n"
                    
            count+=1
                
#print(dataset)
# Out:
# Working for: (2604/2605)qtbase, added, ffef22cae224fd6c575e64a73e5017e5855c9aff.cpp.xml

# %%
pd.DataFrame(dataset).to_csv(ss+'_tp_dataset.csv', index=False, header=False)
