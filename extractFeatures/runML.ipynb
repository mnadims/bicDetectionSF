# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import Perceptron
from sklearn.neighbors import KNeighborsClassifier
from dbn.tensorflow import SupervisedDBNClassification
from sklearn.metrics import precision_recall_fscore_support, confusion_matrix
from sklearn.preprocessing import StandardScaler
from collections import Counter

import tensorflow as tf 
tf.compat.v1.disable_eager_execution()

# %%
def findCorrectBuggy(yTest, yPredict):
    CorrectbuggyCount = 0
    CorrectNonbuggyCount = 0
    for index in range(len(yTest)):
        if(yTest[index] == 1 and yPredict[index] == 1):
            CorrectbuggyCount += 1
        elif(yTest[index] == 0 and yPredict[index] == 0):
            CorrectNonbuggyCount += 1
    print("{}, {}, {}, {}, {}, {}".format(
          Counter(yTest)[1],  
          Counter(yTest)[0],                            
          Counter(yPredict)[1],
          Counter(yPredict)[0],
          CorrectbuggyCount,
          CorrectNonbuggyCount))
#     print("yTest:", Counter(yTest)[1], Counter(yTest)[0],
#           "yPredict:", Counter(yPredict)[1], Counter(yPredict)[0], 
#           "Correct Buggy:", CorrectbuggyCount, 
#           "Correct Non Buggy:", CorrectNonbuggyCount)

def runML(algo, xTrain, xTest, yTrain, yTest):
    if(algo=="lr"):
        #For small datasets, ‘liblinear’ is a good choice, whereas ‘sag’ and ‘saga’ are faster for large ones.
        #Default  max_iter=100 created convergence problem for some cases!!!
        #In this experiment, 'lr' provided ConvergenceWarning: with all the datasets/optimizer. 
        clf = LogisticRegression(random_state=42, solver='liblinear')
    elif(algo=="rf"):
        clf = RandomForestClassifier(random_state=42)
    elif(algo=="knn"):
        clf = KNeighborsClassifier(n_neighbors=5)
    elif(algo=="gbc"):
        clf = GradientBoostingClassifier()
    elif(algo=="pct"):
        clf = Perceptron()
    elif(algo=="dbn"):
        #https://stats.stackexchange.com/questions/181/
        hLayers = int((xTrain.shape[1]+2) / 2) #Hidden Layer Nodes: Mean of Input Layer and Output Layer Nodes.
        if(hLayers < 100):
            hLayers = xTrain.shape[1]
            
        if(hLayers > 2500):
            hLayers = 2500
        
        print("Input Nodes:", xTrain.shape[1], "Hidden Nodes:", hLayers)
            
#         elif(xTrain.shape[0] > 500):
#             hLayers = int(xTrain.shape[0] *0.50)
#         else:
#             hLayers = int(xTrain.shape[0])
            
        clf = SupervisedDBNClassification(hidden_layers_structure =[hLayers], 
                                             learning_rate_rbm=0.0001, 
                                             learning_rate=0.0001, 
                                             n_epochs_rbm=15, 
                                             n_iter_backprop=10, 
                                             batch_size=32, 
                                             activation_function='relu', 
                                             dropout_p=0.20)
        
    clf.fit(xTrain, yTrain)
    
    yPredict = clf.predict(xTest)
    
    #print(Counter(yTest), Counter(yPredict))
    
    #print(confusion_matrix(yTest, yPredict))
    findCorrectBuggy(list(yTest), list(yPredict))
    
    return precision_recall_fscore_support(yTest, yPredict, average='binary')

def runRF(xTrain, xTest, yTrain, yTest, max_depth=100, n_estimators=100):
    clf = RandomForestClassifier(max_depth=100, random_state=42, n_estimators=100)
    clf.fit(xTrain, yTrain)
    yPredict = clf.predict(xTest)    
    return precision_recall_fscore_support(yTest, yPredict, average='binary')

# %%
file_path = "H:/BIC-Review-1/Baselines/JITLine-replication-package-master/JITLine/data/"

qt_gs = pd.read_csv(file_path+ "qt_gs.csv") 
qt_ts = pd.read_csv(file_path+ "qt_ts.csv") 
qt_tp = pd.read_csv(file_path+ "qt_tp.csv") 

openstack_gs = pd.read_csv(file_path+ "openstack_gs.csv") 
openstack_ts = pd.read_csv(file_path+ "openstack_ts.csv") 

for ds in [qt_gs, qt_ts, qt_tp, openstack_gs, openstack_ts]:
    training_size = int(ds.shape[0] * 0.70)
    
    print("Shape:", ds.shape, "Training Size:", training_size)
# Out:
# Shape: (2443, 32) Training Size: 1710
# Shape: (2447, 6465) Training Size: 1712
# Shape: (2443, 4632) Training Size: 1710
# Shape: (1571, 32) Training Size: 1099
# Shape: (1571, 217) Training Size: 1099

# %%
print("QT:", Counter(qt_gs['bugcount']))
print("OpenStack:", Counter(openstack_gs['bugcount']))
# Out:
# QT: Counter({0: 1396, 1: 1047})
# OpenStack: Counter({1: 908, 0: 663})

# %%
qt_gs_ts = pd.merge(qt_gs,
                  qt_ts,
                  on=['commit_id', 'author_date', 'bugcount', 'fixcount'])

qt_gs_tp = pd.merge(qt_gs,
                  qt_tp,
                  on=['commit_id', 'author_date', 'bugcount', 'fixcount'])

qt_ts_tp = pd.merge(qt_ts,
                  qt_tp,
                  on=['commit_id', 'author_date', 'bugcount', 'fixcount'])

qt_gs_ts_tp = pd.merge(pd.merge(qt_gs,
                  qt_ts,
                  on=['commit_id', 'author_date', 'bugcount', 'fixcount']), 
                qt_tp, 
                on=['commit_id', 'author_date', 'bugcount', 'fixcount'])

openstack_gs_ts = pd.merge(openstack_gs,
                  openstack_ts,
                  on=['commit_id', 'author_date', 'bugcount', 'fixcount'])

# %%
for ds in [qt_gs, qt_ts, qt_tp, qt_gs_ts, qt_gs_tp, qt_ts_tp, qt_gs_ts_tp, openstack_gs, openstack_ts, openstack_gs_ts]:
    training_size = int(ds.shape[0] * 0.70)
    
    X = ds.drop(columns=['commit_id', 'author_date', 'bugcount', 'fixcount'])
    Y = ds['bugcount']
    
    trainX = X.iloc[0: training_size, :]
    trainY = Y[0: training_size]
    
    testX = X.iloc[training_size: , :]
    testY = Y[training_size: ]
    
    #print(trainX.shape, trainY.shape, testX.shape, testY.shape)
    
    for algo in ["rf", "knn", "gbc", "pct"]:   
        result=runML(algo, trainX, 
                         testX, 
                         trainY, testY)

        print(algo, [round(float(x), 2) for x in result[0:3]])
    print("--------------")
# Out:
# 220, 513, 179, 554, 89, 423
# rf [0.5, 0.4, 0.45]
# 220, 513, 267, 466, 103, 349
# knn [0.39, 0.47, 0.42]
# 220, 513, 228, 505, 110, 395
# gbc [0.48, 0.5, 0.49]
# 220, 513, 241, 492, 91, 363
# pct [0.38, 0.41, 0.39]
# --------------
# 219, 516, 329, 406, 145, 332
# rf [0.44, 0.66, 0.53]
# 219, 516, 292, 443, 125, 349
# knn [0.43, 0.57, 0.49]
# 219, 516, 280, 455, 127, 363
# gbc [0.45, 0.58, 0.51]
# 219, 516, 508, 227, 159, 167
# pct [0.31, 0.73, 0.44]
# --------------
# 220, 513, 325, 408, 135, 323
# rf [0.42, 0.61, 0.5]
# 220, 513, 213, 520, 81, 381
# knn [0.38, 0.37, 0.37]
# 220, 513, 261, 472, 120, 372
# gbc [0.46, 0.55, 0.5]
# 220, 513, 386, 347, 135, 262
# pct [0.35, 0.61, 0.45]
# --------------
# 219, 511, 290, 440, 138, 359
# rf [0.48, 0.63, 0.54]
# 219, 511, 266, 464, 102, 347
# knn [0.38, 0.47, 0.42]
# 219, 511, 228, 502, 117, 400
# gbc [0.51, 0.53, 0.52]
# 219, 511, 425, 305, 104, 190
# pct [0.24, 0.47, 0.32]
# --------------
# 220, 513, 236, 497, 116, 393
# rf [0.49, 0.53, 0.51]
# 220, 513, 267, 466, 103, 349
# knn [0.39, 0.47, 0.42]
# 220, 513, 209, 524, 105, 409
# gbc [0.5, 0.48, 0.49]
# 220, 513, 241, 492, 91, 363
# pct [0.38, 0.41, 0.39]
# --------------
# 219, 511, 324, 406, 144, 331
# rf [0.44, 0.66, 0.53]
# 219, 511, 281, 449, 118, 348
# knn [0.42, 0.54, 0.47]
# 219, 511, 285, 445, 127, 353
# gbc [0.45, 0.58, 0.5]
# 219, 511, 310, 420, 101, 302
# pct [0.33, 0.46, 0.38]
# --------------
# 219, 511, 291, 439, 136, 356
# rf [0.47, 0.62, 0.53]
# 219, 511, 266, 464, 102, 347
# knn [0.38, 0.47, 0.42]
# 219, 511, 244, 486, 121, 388
# gbc [0.5, 0.55, 0.52]
# 219, 511, 425, 305, 104, 190
# pct [0.24, 0.47, 0.32]
# --------------
# 313, 159, 276, 196, 175, 58
# rf [0.63, 0.56, 0.59]
# 313, 159, 216, 256, 137, 80
# knn [0.63, 0.44, 0.52]
# 313, 159, 276, 196, 174, 57
# gbc [0.63, 0.56, 0.59]
# 313, 159, 336, 136, 222, 45
# pct [0.66, 0.71, 0.68]
# --------------
# 313, 159, 328, 144, 215, 46
# rf [0.66, 0.69, 0.67]
# 313, 159, 275, 197, 177, 61
# knn [0.64, 0.57, 0.6]
# 313, 159, 328, 144, 219, 50
# gbc [0.67, 0.7, 0.68]
# 313, 159, 301, 171, 197, 55
# pct [0.65, 0.63, 0.64]
# --------------
# 313, 159, 304, 168, 194, 49
# rf [0.64, 0.62, 0.63]
# 313, 159, 216, 256, 137, 80
# knn [0.63, 0.44, 0.52]
# 313, 159, 290, 182, 187, 56
# gbc [0.64, 0.6, 0.62]
# 313, 159, 336, 136, 222, 45
# pct [0.66, 0.71, 0.68]
# --------------

# %%
for ds in [qt_gs, qt_ts, qt_tp, qt_gs_ts, qt_gs_tp, qt_ts_tp, qt_gs_ts_tp, openstack_gs, openstack_ts, openstack_gs_ts]:
    training_size = int(ds.shape[0] * 0.70)
    
    X = ds.drop(columns=['commit_id', 'author_date', 'bugcount', 'fixcount'])
    Y = ds['bugcount']
    
    ss=StandardScaler()
    X = ss.fit_transform(X)
    
    trainX = X[0: training_size, :]
    trainY = Y[0: training_size]
    
    testX = X[training_size: , :]
    testY = Y[training_size: ]
    
    for algo in ["dbn"]:   
        result=runML(algo, trainX, 
                         testX, 
                         trainY, testY)

        print(algo, [round(float(x), 2) for x in result[0:3]])
    print("--------------")
# Out:
# Input Nodes: 28 Hidden Nodes: 15
# [START] Pre-training step:
# >> Epoch 1 finished 	RBM Reconstruction error 24.930562
# >> Epoch 2 finished 	RBM Reconstruction error 24.921023
# >> Epoch 3 finished 	RBM Reconstruction error 24.911267
# >> Epoch 4 finished 	RBM Reconstruction error 24.901730
# >> Epoch 5 finished 	RBM Reconstruction error 24.891861
# >> Epoch 6 finished 	RBM Reconstruction error 24.882382
# >> Epoch 7 finished 	RBM Reconstruction error 24.873202
# >> Epoch 8 finished 	RBM Reconstruction error 24.864701
# >> Epoch 9 finished 	RBM Reconstruction error 24.856902
# >> Epoch 10 finished 	RBM Reconstruction error 24.849675
# >> Epoch 11 finished 	RBM Reconstruction error 24.843268
# >> Epoch 12 finished 	RBM Reconstruction error 24.837389
# >> Epoch 13 finished 	RBM Reconstruction error 24.832146
# >> Epoch 14 finished 	RBM Reconstruction error 24.827505
# >> Epoch 15 finished 	RBM Reconstruction error 24.823663
# [END] Pre-training step
# [START] Fine tuning step:
# >> Epoch 0 finished 	ANN training loss 0.693516
# >> Epoch 1 finished 	ANN training loss 0.693509
# >> Epoch 2 finished 	ANN training loss 0.693501
# >> Epoch 3 finished 	ANN training loss 0.693493
# >> Epoch 4 finished 	ANN training loss 0.693485
# >> Epoch 5 finished 	ANN training loss 0.693477
# >> Epoch 6 finished 	ANN training loss 0.693469
# >> Epoch 7 finished 	ANN training loss 0.693462
# >> Epoch 8 finished 	ANN training loss 0.693454
# >> Epoch 9 finished 	ANN training loss 0.693447
# [END] Fine tuning step
# 220 513 292 441 72 293
# dbn [0.25, 0.33, 0.28]
# --------------
# Input Nodes: 6461 Hidden Nodes: 2500
# [START] Pre-training step:
# >> Epoch 1 finished 	RBM Reconstruction error 6719.746323
# >> Epoch 2 finished 	RBM Reconstruction error 6663.207019
# >> Epoch 3 finished 	RBM Reconstruction error 6563.013791
# >> Epoch 4 finished 	RBM Reconstruction error 6448.967516
# >> Epoch 5 finished 	RBM Reconstruction error 6386.964966
# >> Epoch 6 finished 	RBM Reconstruction error 6366.283358
# >> Epoch 7 finished 	RBM Reconstruction error 6340.193409
# >> Epoch 8 finished 	RBM Reconstruction error 6304.696380
# >> Epoch 9 finished 	RBM Reconstruction error 6262.912947
# >> Epoch 10 finished 	RBM Reconstruction error 6217.332167
# >> Epoch 11 finished 	RBM Reconstruction error 6167.558336
# >> Epoch 12 finished 	RBM Reconstruction error 6110.327174
# >> Epoch 13 finished 	RBM Reconstruction error 6056.052330
# >> Epoch 14 finished 	RBM Reconstruction error 5991.691025
# >> Epoch 15 finished 	RBM Reconstruction error 5938.327492
# [END] Pre-training step
# [START] Fine tuning step:
# >> Epoch 0 finished 	ANN training loss 0.690096
# >> Epoch 1 finished 	ANN training loss 0.687600
# >> Epoch 2 finished 	ANN training loss 0.686588
# >> Epoch 3 finished 	ANN training loss 0.685997
# >> Epoch 4 finished 	ANN training loss 0.685410
# >> Epoch 5 finished 	ANN training loss 0.684893
# >> Epoch 6 finished 	ANN training loss 0.684405
# >> Epoch 7 finished 	ANN training loss 0.683936
# >> Epoch 8 finished 	ANN training loss 0.683491
# >> Epoch 9 finished 	ANN training loss 0.683031
# [END] Fine tuning step
# 219 516 242 493 111 385
# dbn [0.46, 0.51, 0.48]
# --------------
# Input Nodes: 4628 Hidden Nodes: 2315
# [START] Pre-training step:
# >> Epoch 1 finished 	RBM Reconstruction error 5401.227765
# >> Epoch 2 finished 	RBM Reconstruction error 5252.499614
# >> Epoch 3 finished 	RBM Reconstruction error 5034.664618
# >> Epoch 4 finished 	RBM Reconstruction error 4781.694554
# >> Epoch 5 finished 	RBM Reconstruction error 4550.008632
# >> Epoch 6 finished 	RBM Reconstruction error 4385.406309
# >> Epoch 7 finished 	RBM Reconstruction error 4287.975914
# >> Epoch 8 finished 	RBM Reconstruction error 4217.236737
# >> Epoch 9 finished 	RBM Reconstruction error 4158.554799
# >> Epoch 10 finished 	RBM Reconstruction error 4087.388033
# >> Epoch 11 finished 	RBM Reconstruction error 4039.245429
# >> Epoch 12 finished 	RBM Reconstruction error 4023.515195
# >> Epoch 13 finished 	RBM Reconstruction error 3988.939980
# >> Epoch 14 finished 	RBM Reconstruction error 4001.545331
# >> Epoch 15 finished 	RBM Reconstruction error 4130.060894
# [END] Pre-training step
# [START] Fine tuning step:
# >> Epoch 0 finished 	ANN training loss 0.687365
# >> Epoch 1 finished 	ANN training loss 0.686535
# >> Epoch 2 finished 	ANN training loss 0.685901
# >> Epoch 3 finished 	ANN training loss 0.685372
# >> Epoch 4 finished 	ANN training loss 0.684896
# >> Epoch 5 finished 	ANN training loss 0.684440
# >> Epoch 6 finished 	ANN training loss 0.684057
# >> Epoch 7 finished 	ANN training loss 0.683702
# >> Epoch 8 finished 	ANN training loss 0.683358
# >> Epoch 9 finished 	ANN training loss 0.683067
# [END] Fine tuning step
# 220 513 238 495 115 390
# dbn [0.48, 0.52, 0.5]
# --------------
# Input Nodes: 6489 Hidden Nodes: 2500
# [START] Pre-training step:
# >> Epoch 1 finished 	RBM Reconstruction error 6716.430779
# >> Epoch 2 finished 	RBM Reconstruction error 6659.011596
# >> Epoch 3 finished 	RBM Reconstruction error 6558.110551
# >> Epoch 4 finished 	RBM Reconstruction error 6444.308802
# >> Epoch 5 finished 	RBM Reconstruction error 6381.807825
# >> Epoch 6 finished 	RBM Reconstruction error 6363.228861
# >> Epoch 7 finished 	RBM Reconstruction error 6338.376982
# >> Epoch 8 finished 	RBM Reconstruction error 6307.947385
# >> Epoch 9 finished 	RBM Reconstruction error 6263.476603
# >> Epoch 10 finished 	RBM Reconstruction error 6216.021010
# >> Epoch 11 finished 	RBM Reconstruction error 6161.525294
# >> Epoch 12 finished 	RBM Reconstruction error 6107.073381
# >> Epoch 13 finished 	RBM Reconstruction error 6058.638816
# >> Epoch 14 finished 	RBM Reconstruction error 5995.110481
# >> Epoch 15 finished 	RBM Reconstruction error 5942.332527
# [END] Pre-training step
# [START] Fine tuning step:
# >> Epoch 0 finished 	ANN training loss 0.686779
# >> Epoch 1 finished 	ANN training loss 0.685367
# >> Epoch 2 finished 	ANN training loss 0.684702
# >> Epoch 3 finished 	ANN training loss 0.684154
# >> Epoch 4 finished 	ANN training loss 0.683693
# >> Epoch 5 finished 	ANN training loss 0.683200
# >> Epoch 6 finished 	ANN training loss 0.682795
# >> Epoch 7 finished 	ANN training loss 0.682383
# >> Epoch 8 finished 	ANN training loss 0.682014
# >> Epoch 9 finished 	ANN training loss 0.681620
# [END] Fine tuning step
# 219 511 224 506 102 389
# dbn [0.46, 0.47, 0.46]
# --------------
# Input Nodes: 4656 Hidden Nodes: 2329
# [START] Pre-training step:
# >> Epoch 1 finished 	RBM Reconstruction error 5425.381391
# >> Epoch 2 finished 	RBM Reconstruction error 5275.292001
# >> Epoch 3 finished 	RBM Reconstruction error 5055.241354
# >> Epoch 4 finished 	RBM Reconstruction error 4799.250828
# >> Epoch 5 finished 	RBM Reconstruction error 4561.538963
# >> Epoch 6 finished 	RBM Reconstruction error 4393.433021
# >> Epoch 7 finished 	RBM Reconstruction error 4300.542259
# >> Epoch 8 finished 	RBM Reconstruction error 4232.745510
# >> Epoch 9 finished 	RBM Reconstruction error 4170.937682
# >> Epoch 10 finished 	RBM Reconstruction error 4119.668170
# >> Epoch 11 finished 	RBM Reconstruction error 4081.438070
# >> Epoch 12 finished 	RBM Reconstruction error 4066.495189
# >> Epoch 13 finished 	RBM Reconstruction error 4023.994987
# >> Epoch 14 finished 	RBM Reconstruction error 4048.143161
# >> Epoch 15 finished 	RBM Reconstruction error 4140.569127
# [END] Pre-training step
# [START] Fine tuning step:
# >> Epoch 0 finished 	ANN training loss 0.688250
# >> Epoch 1 finished 	ANN training loss 0.687109
# >> Epoch 2 finished 	ANN training loss 0.686392
# >> Epoch 3 finished 	ANN training loss 0.685771
# >> Epoch 4 finished 	ANN training loss 0.685251
# >> Epoch 5 finished 	ANN training loss 0.684813
# >> Epoch 6 finished 	ANN training loss 0.684399
# >> Epoch 7 finished 	ANN training loss 0.683989
# >> Epoch 8 finished 	ANN training loss 0.683658
# >> Epoch 9 finished 	ANN training loss 0.683336
# [END] Fine tuning step
# 220 513 231 502 112 394
# dbn [0.48, 0.51, 0.5]
# --------------
# Input Nodes: 11089 Hidden Nodes: 2500
# [START] Pre-training step:
# >> Epoch 1 finished 	RBM Reconstruction error 12114.615012
# >> Epoch 2 finished 	RBM Reconstruction error 11854.618670
# >> Epoch 3 finished 	RBM Reconstruction error 11485.185941
# >> Epoch 4 finished 	RBM Reconstruction error 11265.866578
# >> Epoch 5 finished 	RBM Reconstruction error 11158.587004
# >> Epoch 6 finished 	RBM Reconstruction error 11036.730156
# >> Epoch 7 finished 	RBM Reconstruction error 10851.842799
# >> Epoch 8 finished 	RBM Reconstruction error 10692.399757
# >> Epoch 9 finished 	RBM Reconstruction error 10464.393128
# >> Epoch 10 finished 	RBM Reconstruction error 10311.058631
# >> Epoch 11 finished 	RBM Reconstruction error 10102.186236
# >> Epoch 12 finished 	RBM Reconstruction error 10048.649563
# >> Epoch 13 finished 	RBM Reconstruction error 9934.496160
# >> Epoch 14 finished 	RBM Reconstruction error 9946.059170
# >> Epoch 15 finished 	RBM Reconstruction error 9927.421720
# [END] Pre-training step
# [START] Fine tuning step:
# >> Epoch 0 finished 	ANN training loss 0.685374
# >> Epoch 1 finished 	ANN training loss 0.684074
# >> Epoch 2 finished 	ANN training loss 0.683038
# >> Epoch 3 finished 	ANN training loss 0.683068
# >> Epoch 4 finished 	ANN training loss 0.681369
# >> Epoch 5 finished 	ANN training loss 0.680412
# >> Epoch 6 finished 	ANN training loss 0.679676
# >> Epoch 7 finished 	ANN training loss 0.678979
# >> Epoch 8 finished 	ANN training loss 0.678338
# >> Epoch 9 finished 	ANN training loss 0.677645
# [END] Fine tuning step
# 219 511 237 493 111 385
# dbn [0.47, 0.51, 0.49]
# --------------
# Input Nodes: 11117 Hidden Nodes: 2500
# [START] Pre-training step:
# >> Epoch 1 finished 	RBM Reconstruction error 12139.056347
# >> Epoch 2 finished 	RBM Reconstruction error 11876.983590
# >> Epoch 3 finished 	RBM Reconstruction error 11503.171644
# >> Epoch 4 finished 	RBM Reconstruction error 11289.273671
# >> Epoch 5 finished 	RBM Reconstruction error 11186.545892
# >> Epoch 6 finished 	RBM Reconstruction error 11071.731178
# >> Epoch 7 finished 	RBM Reconstruction error 10947.725550
# >> Epoch 8 finished 	RBM Reconstruction error 10733.918864
# >> Epoch 9 finished 	RBM Reconstruction error 10551.576364
# >> Epoch 10 finished 	RBM Reconstruction error 10368.515070
# >> Epoch 11 finished 	RBM Reconstruction error 10160.532916
# >> Epoch 12 finished 	RBM Reconstruction error 10094.727258
# >> Epoch 13 finished 	RBM Reconstruction error 10003.610169
# >> Epoch 14 finished 	RBM Reconstruction error 9889.369834
# >> Epoch 15 finished 	RBM Reconstruction error 10010.753558
# [END] Pre-training step
# [START] Fine tuning step:
# >> Epoch 0 finished 	ANN training loss 0.683892
# >> Epoch 1 finished 	ANN training loss 0.682781
# >> Epoch 2 finished 	ANN training loss 0.681880
# >> Epoch 3 finished 	ANN training loss 0.680862
# >> Epoch 4 finished 	ANN training loss 0.680128
# >> Epoch 5 finished 	ANN training loss 0.679227
# >> Epoch 6 finished 	ANN training loss 0.678496
# >> Epoch 7 finished 	ANN training loss 0.677798
# >> Epoch 8 finished 	ANN training loss 0.677187
# >> Epoch 9 finished 	ANN training loss 0.676522
# [END] Fine tuning step
# 219 511 225 505 109 395
# dbn [0.48, 0.5, 0.49]
# --------------
# Input Nodes: 28 Hidden Nodes: 15
# [START] Pre-training step:
# >> Epoch 1 finished 	RBM Reconstruction error 25.599925
# >> Epoch 2 finished 	RBM Reconstruction error 25.597089
# >> Epoch 3 finished 	RBM Reconstruction error 25.594241
# >> Epoch 4 finished 	RBM Reconstruction error 25.591390
# >> Epoch 5 finished 	RBM Reconstruction error 25.588536
# >> Epoch 6 finished 	RBM Reconstruction error 25.585645
# >> Epoch 7 finished 	RBM Reconstruction error 25.582810
# >> Epoch 8 finished 	RBM Reconstruction error 25.579964
# >> Epoch 9 finished 	RBM Reconstruction error 25.577185
# >> Epoch 10 finished 	RBM Reconstruction error 25.574244
# >> Epoch 11 finished 	RBM Reconstruction error 25.571412
# >> Epoch 12 finished 	RBM Reconstruction error 25.568735
# >> Epoch 13 finished 	RBM Reconstruction error 25.565961
# >> Epoch 14 finished 	RBM Reconstruction error 25.563190
# >> Epoch 15 finished 	RBM Reconstruction error 25.560307
# [END] Pre-training step
# [START] Fine tuning step:
# >> Epoch 0 finished 	ANN training loss 0.693075
# >> Epoch 1 finished 	ANN training loss 0.693060
# >> Epoch 2 finished 	ANN training loss 0.693044
# >> Epoch 3 finished 	ANN training loss 0.693029
# >> Epoch 4 finished 	ANN training loss 0.693014
# >> Epoch 5 finished 	ANN training loss 0.692998
# >> Epoch 6 finished 	ANN training loss 0.692982
# >> Epoch 7 finished 	ANN training loss 0.692968
# >> Epoch 8 finished 	ANN training loss 0.692952
# >> Epoch 9 finished 	ANN training loss 0.692937
# [END] Fine tuning step
# 313 159 132 340 86 113
# dbn [0.65, 0.27, 0.39]
# --------------
# Input Nodes: 213 Hidden Nodes: 107
# [START] Pre-training step:
# >> Epoch 1 finished 	RBM Reconstruction error 238.809969
# >> Epoch 2 finished 	RBM Reconstruction error 238.739558
# >> Epoch 3 finished 	RBM Reconstruction error 238.656192
# >> Epoch 4 finished 	RBM Reconstruction error 238.562970
# >> Epoch 5 finished 	RBM Reconstruction error 238.457149
# >> Epoch 6 finished 	RBM Reconstruction error 238.339039
# >> Epoch 7 finished 	RBM Reconstruction error 238.204793
# >> Epoch 8 finished 	RBM Reconstruction error 238.053152
# >> Epoch 9 finished 	RBM Reconstruction error 237.884868
# >> Epoch 10 finished 	RBM Reconstruction error 237.693456
# >> Epoch 11 finished 	RBM Reconstruction error 237.480093
# >> Epoch 12 finished 	RBM Reconstruction error 237.243420
# >> Epoch 13 finished 	RBM Reconstruction error 236.980069
# >> Epoch 14 finished 	RBM Reconstruction error 236.693309
# >> Epoch 15 finished 	RBM Reconstruction error 236.370534
# [END] Pre-training step
# [START] Fine tuning step:
# >> Epoch 0 finished 	ANN training loss 0.693732
# >> Epoch 1 finished 	ANN training loss 0.693690
# >> Epoch 2 finished 	ANN training loss 0.693647
# >> Epoch 3 finished 	ANN training loss 0.693604
# >> Epoch 4 finished 	ANN training loss 0.693557
# >> Epoch 5 finished 	ANN training loss 0.693512
# >> Epoch 6 finished 	ANN training loss 0.693468
# >> Epoch 7 finished 	ANN training loss 0.693427
# >> Epoch 8 finished 	ANN training loss 0.693380
# >> Epoch 9 finished 	ANN training loss 0.693338
# [END] Fine tuning step
# 313 159 340 132 228 47
# dbn [0.67, 0.73, 0.7]
# --------------
# Input Nodes: 241 Hidden Nodes: 121
# [START] Pre-training step:
# >> Epoch 1 finished 	RBM Reconstruction error 264.450794
# >> Epoch 2 finished 	RBM Reconstruction error 264.389416
# >> Epoch 3 finished 	RBM Reconstruction error 264.319961
# >> Epoch 4 finished 	RBM Reconstruction error 264.240595
# >> Epoch 5 finished 	RBM Reconstruction error 264.151064
# >> Epoch 6 finished 	RBM Reconstruction error 264.052219
# >> Epoch 7 finished 	RBM Reconstruction error 263.938795
# >> Epoch 8 finished 	RBM Reconstruction error 263.808742
# >> Epoch 9 finished 	RBM Reconstruction error 263.666171
# >> Epoch 10 finished 	RBM Reconstruction error 263.506327
# >> Epoch 11 finished 	RBM Reconstruction error 263.324487
# >> Epoch 12 finished 	RBM Reconstruction error 263.122625
# >> Epoch 13 finished 	RBM Reconstruction error 262.888732
# >> Epoch 14 finished 	RBM Reconstruction error 262.625562
# >> Epoch 15 finished 	RBM Reconstruction error 262.330207
# [END] Pre-training step
# [START] Fine tuning step:
# >> Epoch 0 finished 	ANN training loss 0.694786
# >> Epoch 1 finished 	ANN training loss 0.694739
# >> Epoch 2 finished 	ANN training loss 0.694693
# >> Epoch 3 finished 	ANN training loss 0.694643
# >> Epoch 4 finished 	ANN training loss 0.694595
# >> Epoch 5 finished 	ANN training loss 0.694549
# >> Epoch 6 finished 	ANN training loss 0.694498
# >> Epoch 7 finished 	ANN training loss 0.694453
# >> Epoch 8 finished 	ANN training loss 0.694410
# >> Epoch 9 finished 	ANN training loss 0.694366
# [END] Fine tuning step
# 313 159 215 257 142 86
# dbn [0.66, 0.45, 0.54]
# --------------

# %%
for ds in [qt_gs, qt_ts, qt_tp, qt_gs_ts, qt_gs_tp, qt_ts_tp, qt_gs_ts_tp, openstack_gs, openstack_ts, openstack_gs_ts]:
    training_size = int(ds.shape[0] * 0.70)
    
    X = ds.drop(columns=['commit_id', 'author_date', 'bugcount', 'fixcount'])
    Y = ds['bugcount']
    
    ss=StandardScaler()
    X = ss.fit_transform(X)
    
    trainX = X[0: training_size, :]
    trainY = Y[0: training_size]
    
    testX = X[training_size: , :]
    testY = Y[training_size: ]
    
    for algo in ["dbn"]:   
        result=runML(algo, trainX, 
                         testX, 
                         trainY, testY)

        print(algo, [round(float(x), 2) for x in result[0:3]])
    print("--------------")
# Out:
# Input Nodes: 28 Hidden Nodes: 28
# [START] Pre-training step:
# >> Epoch 1 finished 	RBM Reconstruction error 24.830735
# >> Epoch 2 finished 	RBM Reconstruction error 24.820828
# >> Epoch 3 finished 	RBM Reconstruction error 24.810973
# >> Epoch 4 finished 	RBM Reconstruction error 24.801591
# >> Epoch 5 finished 	RBM Reconstruction error 24.792341
# >> Epoch 6 finished 	RBM Reconstruction error 24.783740
# >> Epoch 7 finished 	RBM Reconstruction error 24.775177
# >> Epoch 8 finished 	RBM Reconstruction error 24.767218
# >> Epoch 9 finished 	RBM Reconstruction error 24.760063
# >> Epoch 10 finished 	RBM Reconstruction error 24.753389
# >> Epoch 11 finished 	RBM Reconstruction error 24.747713
# >> Epoch 12 finished 	RBM Reconstruction error 24.742929
# >> Epoch 13 finished 	RBM Reconstruction error 24.738936
# >> Epoch 14 finished 	RBM Reconstruction error 24.735686
# >> Epoch 15 finished 	RBM Reconstruction error 24.732630
# [END] Pre-training step
# [START] Fine tuning step:
# >> Epoch 0 finished 	ANN training loss 0.693794
# >> Epoch 1 finished 	ANN training loss 0.693785
# >> Epoch 2 finished 	ANN training loss 0.693776
# >> Epoch 3 finished 	ANN training loss 0.693767
# >> Epoch 4 finished 	ANN training loss 0.693759
# >> Epoch 5 finished 	ANN training loss 0.693750
# >> Epoch 6 finished 	ANN training loss 0.693741
# >> Epoch 7 finished 	ANN training loss 0.693732
# >> Epoch 8 finished 	ANN training loss 0.693723
# >> Epoch 9 finished 	ANN training loss 0.693715
# [END] Fine tuning step
# 220 513 629 104 192 76
# dbn [0.31, 0.87, 0.45]
# --------------
# Input Nodes: 6461 Hidden Nodes: 2500
# [START] Pre-training step:
# >> Epoch 1 finished 	RBM Reconstruction error 6719.865514
# >> Epoch 2 finished 	RBM Reconstruction error 6664.744196
# >> Epoch 3 finished 	RBM Reconstruction error 6566.620423
# >> Epoch 4 finished 	RBM Reconstruction error 6452.613789
# >> Epoch 5 finished 	RBM Reconstruction error 6389.813600
# >> Epoch 6 finished 	RBM Reconstruction error 6365.793707
# >> Epoch 7 finished 	RBM Reconstruction error 6340.251742
# >> Epoch 8 finished 	RBM Reconstruction error 6304.978031
# >> Epoch 9 finished 	RBM Reconstruction error 6267.157415
# >> Epoch 10 finished 	RBM Reconstruction error 6214.786848
# >> Epoch 11 finished 	RBM Reconstruction error 6166.894603
# >> Epoch 12 finished 	RBM Reconstruction error 6115.521208
# >> Epoch 13 finished 	RBM Reconstruction error 6053.579449
# >> Epoch 14 finished 	RBM Reconstruction error 5996.059691
# >> Epoch 15 finished 	RBM Reconstruction error 5936.091870
# [END] Pre-training step
# [START] Fine tuning step:
# >> Epoch 0 finished 	ANN training loss 0.687664
# >> Epoch 1 finished 	ANN training loss 0.686190
# >> Epoch 2 finished 	ANN training loss 0.685384
# >> Epoch 3 finished 	ANN training loss 0.684774
# >> Epoch 4 finished 	ANN training loss 0.684254
# >> Epoch 5 finished 	ANN training loss 0.683771
# >> Epoch 6 finished 	ANN training loss 0.683307
# >> Epoch 7 finished 	ANN training loss 0.682837
# >> Epoch 8 finished 	ANN training loss 0.682405
# >> Epoch 9 finished 	ANN training loss 0.682001
# [END] Fine tuning step
# 219 516 233 502 107 390
# dbn [0.46, 0.49, 0.47]
# --------------
# Input Nodes: 4628 Hidden Nodes: 2315
# [START] Pre-training step:
# >> Epoch 1 finished 	RBM Reconstruction error 5402.440451
# >> Epoch 2 finished 	RBM Reconstruction error 5255.253946
# >> Epoch 3 finished 	RBM Reconstruction error 5038.241699
# >> Epoch 4 finished 	RBM Reconstruction error 4784.226642
# >> Epoch 5 finished 	RBM Reconstruction error 4547.714694
# >> Epoch 6 finished 	RBM Reconstruction error 4374.755976
# >> Epoch 7 finished 	RBM Reconstruction error 4274.394273
# >> Epoch 8 finished 	RBM Reconstruction error 4211.809250
# >> Epoch 9 finished 	RBM Reconstruction error 4145.636374
# >> Epoch 10 finished 	RBM Reconstruction error 4081.165540
# >> Epoch 11 finished 	RBM Reconstruction error 4043.876448
# >> Epoch 12 finished 	RBM Reconstruction error 4021.848730
# >> Epoch 13 finished 	RBM Reconstruction error 4049.365287
# >> Epoch 14 finished 	RBM Reconstruction error 4080.023678
# >> Epoch 15 finished 	RBM Reconstruction error 4160.385365
# [END] Pre-training step
# [START] Fine tuning step:
# >> Epoch 0 finished 	ANN training loss 0.687681
# >> Epoch 1 finished 	ANN training loss 0.686488
# >> Epoch 2 finished 	ANN training loss 0.685797
# >> Epoch 3 finished 	ANN training loss 0.685270
# >> Epoch 4 finished 	ANN training loss 0.684815
# >> Epoch 5 finished 	ANN training loss 0.684389
# >> Epoch 6 finished 	ANN training loss 0.684026
# >> Epoch 7 finished 	ANN training loss 0.683688
# >> Epoch 8 finished 	ANN training loss 0.683365
# >> Epoch 9 finished 	ANN training loss 0.683063
# [END] Fine tuning step
# 220 513 243 490 114 384
# dbn [0.47, 0.52, 0.49]
# --------------
# Input Nodes: 6489 Hidden Nodes: 2500
# [START] Pre-training step:
# >> Epoch 1 finished 	RBM Reconstruction error 6716.677581
# >> Epoch 2 finished 	RBM Reconstruction error 6660.021379
# >> Epoch 3 finished 	RBM Reconstruction error 6559.555336
# >> Epoch 4 finished 	RBM Reconstruction error 6445.128303
# >> Epoch 5 finished 	RBM Reconstruction error 6384.341304
# >> Epoch 6 finished 	RBM Reconstruction error 6363.994992
# >> Epoch 7 finished 	RBM Reconstruction error 6339.220498
# >> Epoch 8 finished 	RBM Reconstruction error 6306.735674
# >> Epoch 9 finished 	RBM Reconstruction error 6261.328539
# >> Epoch 10 finished 	RBM Reconstruction error 6214.651225
# >> Epoch 11 finished 	RBM Reconstruction error 6167.476923
# >> Epoch 12 finished 	RBM Reconstruction error 6115.810648
# >> Epoch 13 finished 	RBM Reconstruction error 6054.385422
# >> Epoch 14 finished 	RBM Reconstruction error 5991.457875
# >> Epoch 15 finished 	RBM Reconstruction error 5939.665405
# [END] Pre-training step
# [START] Fine tuning step:
# >> Epoch 0 finished 	ANN training loss 0.687398
# >> Epoch 1 finished 	ANN training loss 0.685839
# >> Epoch 2 finished 	ANN training loss 0.685005
# >> Epoch 3 finished 	ANN training loss 0.684451
# >> Epoch 4 finished 	ANN training loss 0.683964
# >> Epoch 5 finished 	ANN training loss 0.683517
# >> Epoch 6 finished 	ANN training loss 0.683245
# >> Epoch 7 finished 	ANN training loss 0.682629
# >> Epoch 8 finished 	ANN training loss 0.682184
# >> Epoch 9 finished 	ANN training loss 0.681787
# [END] Fine tuning step
# 219 511 239 491 108 380
# dbn [0.45, 0.49, 0.47]
# --------------
# Input Nodes: 4656 Hidden Nodes: 2329
# [START] Pre-training step:
# >> Epoch 1 finished 	RBM Reconstruction error 5425.986287
# >> Epoch 2 finished 	RBM Reconstruction error 5277.135754
# >> Epoch 3 finished 	RBM Reconstruction error 5058.760596
# >> Epoch 4 finished 	RBM Reconstruction error 4804.857834
# >> Epoch 5 finished 	RBM Reconstruction error 4571.598721
# >> Epoch 6 finished 	RBM Reconstruction error 4403.271867
# >> Epoch 7 finished 	RBM Reconstruction error 4307.792499
# >> Epoch 8 finished 	RBM Reconstruction error 4237.868928
# >> Epoch 9 finished 	RBM Reconstruction error 4187.976705
# >> Epoch 10 finished 	RBM Reconstruction error 4132.884123
# >> Epoch 11 finished 	RBM Reconstruction error 4090.112741
# >> Epoch 12 finished 	RBM Reconstruction error 4047.146242
# >> Epoch 13 finished 	RBM Reconstruction error 4028.355892
# >> Epoch 14 finished 	RBM Reconstruction error 4101.573771
# >> Epoch 15 finished 	RBM Reconstruction error 4199.613333
# [END] Pre-training step
# [START] Fine tuning step:
# >> Epoch 0 finished 	ANN training loss 0.686930
# >> Epoch 1 finished 	ANN training loss 0.686354
# >> Epoch 2 finished 	ANN training loss 0.685844
# >> Epoch 3 finished 	ANN training loss 0.685406
# >> Epoch 4 finished 	ANN training loss 0.684965
# >> Epoch 5 finished 	ANN training loss 0.684589
# >> Epoch 6 finished 	ANN training loss 0.684234
# >> Epoch 7 finished 	ANN training loss 0.683887
# >> Epoch 8 finished 	ANN training loss 0.683587
# >> Epoch 9 finished 	ANN training loss 0.683304
# [END] Fine tuning step
# 220 513 238 495 113 388
# dbn [0.47, 0.51, 0.49]
# --------------
# Input Nodes: 11089 Hidden Nodes: 2500
# [START] Pre-training step:
# >> Epoch 1 finished 	RBM Reconstruction error 12113.937778
# >> Epoch 2 finished 	RBM Reconstruction error 11849.168103
# >> Epoch 3 finished 	RBM Reconstruction error 11470.410639
# >> Epoch 4 finished 	RBM Reconstruction error 11253.007427
# >> Epoch 5 finished 	RBM Reconstruction error 11153.861491
# >> Epoch 6 finished 	RBM Reconstruction error 11063.204587
# >> Epoch 7 finished 	RBM Reconstruction error 10858.410287
# >> Epoch 8 finished 	RBM Reconstruction error 10682.339442
# >> Epoch 9 finished 	RBM Reconstruction error 10529.018591
# >> Epoch 10 finished 	RBM Reconstruction error 10331.831056
# >> Epoch 11 finished 	RBM Reconstruction error 10200.482435
# >> Epoch 12 finished 	RBM Reconstruction error 10052.518127
# >> Epoch 13 finished 	RBM Reconstruction error 10011.869177
# >> Epoch 14 finished 	RBM Reconstruction error 9930.736882
# >> Epoch 15 finished 	RBM Reconstruction error 9930.964099
# [END] Pre-training step
# [START] Fine tuning step:
# >> Epoch 0 finished 	ANN training loss 0.684557
# >> Epoch 1 finished 	ANN training loss 0.683350
# >> Epoch 2 finished 	ANN training loss 0.682475
# >> Epoch 3 finished 	ANN training loss 0.681589
# >> Epoch 4 finished 	ANN training loss 0.680912
# >> Epoch 5 finished 	ANN training loss 0.680008
# >> Epoch 6 finished 	ANN training loss 0.679316
# >> Epoch 7 finished 	ANN training loss 0.678657
# >> Epoch 8 finished 	ANN training loss 0.678057
# >> Epoch 9 finished 	ANN training loss 0.677472
# [END] Fine tuning step
# 219 511 229 501 106 388
# dbn [0.46, 0.48, 0.47]
# --------------
# Input Nodes: 11117 Hidden Nodes: 2500
# [START] Pre-training step:
# >> Epoch 1 finished 	RBM Reconstruction error 12140.535316
# >> Epoch 2 finished 	RBM Reconstruction error 11879.287387
# >> Epoch 3 finished 	RBM Reconstruction error 11501.732425
# >> Epoch 4 finished 	RBM Reconstruction error 11274.274675
# >> Epoch 5 finished 	RBM Reconstruction error 11172.653538
# >> Epoch 6 finished 	RBM Reconstruction error 11061.464043
# >> Epoch 7 finished 	RBM Reconstruction error 10880.240759
# >> Epoch 8 finished 	RBM Reconstruction error 10681.941028
# >> Epoch 9 finished 	RBM Reconstruction error 10480.604031
# >> Epoch 10 finished 	RBM Reconstruction error 10301.545556
# >> Epoch 11 finished 	RBM Reconstruction error 10184.125089
# >> Epoch 12 finished 	RBM Reconstruction error 10079.959579
# >> Epoch 13 finished 	RBM Reconstruction error 10007.481386
# >> Epoch 14 finished 	RBM Reconstruction error 9988.925523
# >> Epoch 15 finished 	RBM Reconstruction error 10046.279239
# [END] Pre-training step
# [START] Fine tuning step:
# >> Epoch 0 finished 	ANN training loss 0.684617
# >> Epoch 1 finished 	ANN training loss 0.683553
# >> Epoch 2 finished 	ANN training loss 0.682655
# >> Epoch 3 finished 	ANN training loss 0.682018
# >> Epoch 4 finished 	ANN training loss 0.682827
# >> Epoch 5 finished 	ANN training loss 0.680448
# >> Epoch 6 finished 	ANN training loss 0.679630
# >> Epoch 7 finished 	ANN training loss 0.678976
# >> Epoch 8 finished 	ANN training loss 0.678336
# >> Epoch 9 finished 	ANN training loss 0.677755
# [END] Fine tuning step
# 219 511 238 492 114 387
# dbn [0.48, 0.52, 0.5]
# --------------
# Input Nodes: 28 Hidden Nodes: 28
# [START] Pre-training step:
# >> Epoch 1 finished 	RBM Reconstruction error 25.504479
# >> Epoch 2 finished 	RBM Reconstruction error 25.500678
# >> Epoch 3 finished 	RBM Reconstruction error 25.496717
# >> Epoch 4 finished 	RBM Reconstruction error 25.492928
# >> Epoch 5 finished 	RBM Reconstruction error 25.488893
# >> Epoch 6 finished 	RBM Reconstruction error 25.484914
# >> Epoch 7 finished 	RBM Reconstruction error 25.480829
# >> Epoch 8 finished 	RBM Reconstruction error 25.476788
# >> Epoch 9 finished 	RBM Reconstruction error 25.472752
# >> Epoch 10 finished 	RBM Reconstruction error 25.468789
# >> Epoch 11 finished 	RBM Reconstruction error 25.464905
# >> Epoch 12 finished 	RBM Reconstruction error 25.461147
# >> Epoch 13 finished 	RBM Reconstruction error 25.457116
# >> Epoch 14 finished 	RBM Reconstruction error 25.453014
# >> Epoch 15 finished 	RBM Reconstruction error 25.448877
# [END] Pre-training step
# [START] Fine tuning step:
# >> Epoch 0 finished 	ANN training loss 0.693563
# >> Epoch 1 finished 	ANN training loss 0.693548
# >> Epoch 2 finished 	ANN training loss 0.693532
# >> Epoch 3 finished 	ANN training loss 0.693518
# >> Epoch 4 finished 	ANN training loss 0.693503
# >> Epoch 5 finished 	ANN training loss 0.693489
# >> Epoch 6 finished 	ANN training loss 0.693473
# >> Epoch 7 finished 	ANN training loss 0.693457
# >> Epoch 8 finished 	ANN training loss 0.693442
# >> Epoch 9 finished 	ANN training loss 0.693427
# [END] Fine tuning step
# 313 159 318 154 211 52
# dbn [0.66, 0.67, 0.67]
# --------------
# Input Nodes: 213 Hidden Nodes: 107
# [START] Pre-training step:
# >> Epoch 1 finished 	RBM Reconstruction error 238.909446
# >> Epoch 2 finished 	RBM Reconstruction error 238.856461
# >> Epoch 3 finished 	RBM Reconstruction error 238.796538
# >> Epoch 4 finished 	RBM Reconstruction error 238.731868
# >> Epoch 5 finished 	RBM Reconstruction error 238.658722
# >> Epoch 6 finished 	RBM Reconstruction error 238.572939
# >> Epoch 7 finished 	RBM Reconstruction error 238.479443
# >> Epoch 8 finished 	RBM Reconstruction error 238.375244
# >> Epoch 9 finished 	RBM Reconstruction error 238.261439
# >> Epoch 10 finished 	RBM Reconstruction error 238.129363
# >> Epoch 11 finished 	RBM Reconstruction error 237.982514
# >> Epoch 12 finished 	RBM Reconstruction error 237.820883
# >> Epoch 13 finished 	RBM Reconstruction error 237.641098
# >> Epoch 14 finished 	RBM Reconstruction error 237.432880
# >> Epoch 15 finished 	RBM Reconstruction error 237.203340
# [END] Pre-training step
# [START] Fine tuning step:
# >> Epoch 0 finished 	ANN training loss 0.694049
# >> Epoch 1 finished 	ANN training loss 0.694014
# >> Epoch 2 finished 	ANN training loss 0.693981
# >> Epoch 3 finished 	ANN training loss 0.693946
# >> Epoch 4 finished 	ANN training loss 0.693912
# >> Epoch 5 finished 	ANN training loss 0.693877
# >> Epoch 6 finished 	ANN training loss 0.693841
# >> Epoch 7 finished 	ANN training loss 0.693805
# >> Epoch 8 finished 	ANN training loss 0.693771
# >> Epoch 9 finished 	ANN training loss 0.693738
# [END] Fine tuning step
# 313 159 335 137 214 38
# dbn [0.64, 0.68, 0.66]
# --------------
# Input Nodes: 241 Hidden Nodes: 121
# [START] Pre-training step:
# >> Epoch 1 finished 	RBM Reconstruction error 264.404315
# >> Epoch 2 finished 	RBM Reconstruction error 264.336749
# >> Epoch 3 finished 	RBM Reconstruction error 264.261647
# >> Epoch 4 finished 	RBM Reconstruction error 264.178846
# >> Epoch 5 finished 	RBM Reconstruction error 264.083700
# >> Epoch 6 finished 	RBM Reconstruction error 263.973736
# >> Epoch 7 finished 	RBM Reconstruction error 263.851758
# >> Epoch 8 finished 	RBM Reconstruction error 263.713696
# >> Epoch 9 finished 	RBM Reconstruction error 263.559058
# >> Epoch 10 finished 	RBM Reconstruction error 263.389624
# >> Epoch 11 finished 	RBM Reconstruction error 263.196806
# >> Epoch 12 finished 	RBM Reconstruction error 262.975988
# >> Epoch 13 finished 	RBM Reconstruction error 262.732278
# >> Epoch 14 finished 	RBM Reconstruction error 262.458152
# >> Epoch 15 finished 	RBM Reconstruction error 262.152303
# [END] Pre-training step
# [START] Fine tuning step:
# >> Epoch 0 finished 	ANN training loss 0.693927
# >> Epoch 1 finished 	ANN training loss 0.693881
# >> Epoch 2 finished 	ANN training loss 0.693835
# >> Epoch 3 finished 	ANN training loss 0.693791
# >> Epoch 4 finished 	ANN training loss 0.693746
# >> Epoch 5 finished 	ANN training loss 0.693700
# >> Epoch 6 finished 	ANN training loss 0.693657
# >> Epoch 7 finished 	ANN training loss 0.693614
# >> Epoch 8 finished 	ANN training loss 0.693573
# >> Epoch 9 finished 	ANN training loss 0.693530
# [END] Fine tuning step
# 313 159 342 130 225 42
# dbn [0.66, 0.72, 0.69]
# --------------

# %%
Counter([1, 2, 1, 2, 1, 1])[1]
# Out:
# 4

# %%
ExcludedAutoSpearman = open(file_path+"../ranked_feature_names/excludeAutoSpearman.txt").read().split('\n')[0:-1]
print(len(ExcludedAutoSpearman), len(qt_tp.columns))
importantFeatures = []
for c in qt_tp.columns:
    if c not in ExcludedAutoSpearman:
        importantFeatures.append(c)

print(len(importantFeatures))
# Out:
# 2992 4632
# 1704

# %%
# for ds in [qt_gs, qt_ts, qt_tp, openstack_gs, openstack_ts]:
for ds in [qt_tp]:
    training_size = int(ds.shape[0] * 0.70)
    
    X = ds[importantFeatures].drop(columns=['commit_id', 'author_date', 'bugcount', 'fixcount'])
    Y = ds['bugcount']
    
    ss=StandardScaler()
    X = ss.fit_transform(X)
    
    trainX = X[0: training_size, :]
    trainY = Y[0: training_size]
    
    testX = X[training_size: , :]
    testY = Y[training_size: ]
    
    for algo in ["dbn"]:   
        result=runML(algo, trainX, 
                         testX, 
                         trainY, testY)

        print(algo, [round(float(x), 2) for x in result[0:3]])
    print("--------------")
# Out:
# [START] Pre-training step:
# >> Epoch 1 finished 	RBM Reconstruction error 1675.878165
# >> Epoch 2 finished 	RBM Reconstruction error 1674.296602
# >> Epoch 3 finished 	RBM Reconstruction error 1672.147958
# >> Epoch 4 finished 	RBM Reconstruction error 1669.355983
# >> Epoch 5 finished 	RBM Reconstruction error 1665.863487
# >> Epoch 6 finished 	RBM Reconstruction error 1661.572489
# >> Epoch 7 finished 	RBM Reconstruction error 1656.441172
# >> Epoch 8 finished 	RBM Reconstruction error 1650.456078
# >> Epoch 9 finished 	RBM Reconstruction error 1643.563776
# >> Epoch 10 finished 	RBM Reconstruction error 1635.801804
# >> Epoch 11 finished 	RBM Reconstruction error 1627.208685
# >> Epoch 12 finished 	RBM Reconstruction error 1617.971643
# >> Epoch 13 finished 	RBM Reconstruction error 1608.326682
# >> Epoch 14 finished 	RBM Reconstruction error 1598.623935
# >> Epoch 15 finished 	RBM Reconstruction error 1589.285727
# [END] Pre-training step
# [START] Fine tuning step:
# >> Epoch 0 finished 	ANN training loss 0.691617
# >> Epoch 1 finished 	ANN training loss 0.691270
# >> Epoch 2 finished 	ANN training loss 0.690934
# >> Epoch 3 finished 	ANN training loss 0.690634
# >> Epoch 4 finished 	ANN training loss 0.690391
# >> Epoch 5 finished 	ANN training loss 0.690151
# >> Epoch 6 finished 	ANN training loss 0.689938
# >> Epoch 7 finished 	ANN training loss 0.689757
# >> Epoch 8 finished 	ANN training loss 0.689591
# >> Epoch 9 finished 	ANN training loss 0.689420
# [END] Fine tuning step
# yTest: Counter({0: 513, 1: 220}) yPredict: Counter({0: 489, 1: 244}) Correct Buggy: 113 Correct Non Buggy: 382
# dbn [0.46, 0.51, 0.49]
# --------------
